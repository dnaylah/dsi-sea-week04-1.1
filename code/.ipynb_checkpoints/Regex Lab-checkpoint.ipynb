# %%
import requests
import random
import numpy as np

word_site = "http://svnweb.freebsd.org/csrg/share/dict/words?view=co&content-type=text/plain"
response = requests.get(word_site)
WORDS = response.content.splitlines()
proper = [word for word in WORDS if word[0].isupper()]
not_proper = [word for word in WORDS if not word[0].isupper()]

class formWords:
    def __init__(self, proper, not_proper):
        self.proper = proper
        self.not_proper = not_proper
        
    def randomProper(self):
        return self.proper[np.random.randint(0,len(self.proper))]
    
    def randomNonProper(self):
        return self.not_proper[np.random.randint(0,len(self.not_proper))]
        
    def randomNumber(self,digits):
        return str(random.sample(range(10 ** (digits - 1), 10 ** (digits)), 1)[0])
    
    def randomPostfix(self):
        postfix = ['Street','Ave', 'Blvd', 'Lane', 'Court']
        return postfix[np.random.randint(1,len(postfix))]
    
    def randomEmailProvider(self):
        provider = ['gmail','yahoo', 'live', 'compuserve', 'aol']
        return provider[np.random.randint(1,len(provider))]
    
    def randomState(self):
        states = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DC", "DE", "FL", "GA", 
          "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", 
          "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", 
          "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", 
          "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"]
        return states[np.random.randint(1,len(states))]
        
    def generateText(self, blog_length):
        form = self.getForm()
        blog = []
        for x in range(blog_length):
            choice = np.random.randint(1,50)
            if choice < 38:
                blog += [self.randomNonProper()]
            elif choice < 40:
                blog += [form['email']()]
            elif choice < 44:
                blog += [form['name']()]
            elif choice < 46:
                blog += [form['password']()]
            elif choice < 50:
                blog += [form['address']()]
    
        return " ".join(blog)

    def getForm(self):
        return {
            'email' : lambda : "Email: " + self.randomNumber(4) + self.randomNonProper().lower() + 
                "@" + self.randomEmailProvider() + ".com",
            'name' : lambda : "Name: " + self.randomProper() + " " + self.randomProper(),
            'password' : lambda : "Password: " + self.randomNumber(2) + self.randomNonProper() + 
                self.randomNumber(3) + self.randomProper().lower(),
            'address' : lambda : "Address: " + self.randomNumber(3) + " " + self.randomProper() + 
                " " + self.randomPostfix() + ", " + self.randomProper() + " " + self.randomState() + 
                ", " + self.randomNumber(5),
        }

words = formWords(proper, not_proper)

# %%
import re

# %%
print words.getForm()['email']()
print words.getForm()['name']()
print words.getForm()['password']()
print words.getForm()['address']()

#This is the data variable
data = words.generateText(10000)
print data[:100]
# Out:
# Email: 7076redwood@compuserve.com
# Name: Getty Tuesday
# Password: 70brandish460sean
# Address: 561 Irvine Blvd, Poughkeepsie NV, 61125
# buoy reparation Address: 820 Blackman Blvd, Yokohama WA, 92585 sweeten alternate papaw borosilicate

# %% [markdown]
# ### Pull all the emails from the data variable

# %%
emaills = re.findall('\s+([0-9]{4}[a-z]*@[a-z]*.com)',data)
emaills
# Out:
# ['8899fidget@compuserve.com',
#  '6421comparator@live.com',
#  '5864owe@yahoo.com',
#  '8826postwar@compuserve.com',
#  '3294silty@live.com',
#  '6655arginine@aol.com',
#  '8375surplus@live.com',
#  '4851wildcat@aol.com',
#  '4990pastiche@yahoo.com',
#  '1688complement@aol.com',
#  '3548bootlegger@aol.com',
#  '2731income@aol.com',
#  '6604diary@yahoo.com',
#  '7876aster@live.com',
#  '6769cagey@compuserve.com',
#  '5395quatrain@compuserve.com',
#  '5212aloft@aol.com',
#  '8442wholesale@compuserve.com',
#  '1637intimacy@compuserve.com',
#  '1448deltoid@compuserve.com',
#  '8798brig@live.com',
#  '6785cytoplasm@compuserve.com',
#  '9413loathsome@yahoo.com',
#  '2495safe@yahoo.com',
#  '5842parody@compuserve.com',
#  '5122stopcock@live.com',
#  '9317corundum@live.com',
#  '3413chord@aol.com',
#  '6399loanword@compuserve.com',
#  '3760inclusion@live.com',
#  '5196transference@live.com',
#  '5470burl@live.com',
#  '6825putty@aol.com',
#  '7895filtrate@yahoo.com',
#  '7691exciton@yahoo.com',
#  '8485nineteenth@compuserve.com',
#  '2094eardrum@yahoo.com',
#  '7711attribute@compuserve.com',
#  '9558intestine@aol.com',
#  '5701breach@aol.com',
#  '8090truism@live.com',
#  '7393oyster@aol.com',
#  '9587jellyfish@compuserve.com',
#  '9852windblown@aol.com',
#  '3593checksummed@yahoo.com',
#  '4268inauthentic@yahoo.com',
#  '1488chloroform@compuserve.com',
#  '3448stealthy@aol.com',
#  '8876glucose@yahoo.com',
#  '3640poesy@aol.com',
#  '9285trig@live.com',
#  '4736ornamentation@live.com',
#  '4376bodhisattva@yahoo.com',
#  '3640anthropogenic@live.com',
#  '6778incomputable@aol.com',
#  '9511penalty@live.com',
#  '1855diamagnetic@compuserve.com',
#  '9752marry@compuserve.com',
#  '9083lifeblood@live.com',
#  '1962drew@live.com',
#  '3508hardtack@live.com',
#  '1018whereabout@aol.com',
#  '4721bronco@aol.com',
#  '1521automobile@live.com',
#  '4684fiancee@live.com',
#  '3326ouch@live.com',
#  '1256warn@aol.com',
#  '6403breakage@aol.com',
#  '6689calculable@yahoo.com',
#  '7878mandatory@compuserve.com',
#  '7503canto@live.com',
#  '1149oboe@aol.com',
#  '8269typology@live.com',
#  '2985lackadaisic@compuserve.com',
#  '4947doctoral@yahoo.com',
#  '6865coffeecup@compuserve.com',
#  '2647diadem@live.com',
#  '5828countersink@compuserve.com',
#  '5769querulous@compuserve.com',
#  '8116statute@live.com',
#  '6131daylight@compuserve.com',
#  '6156ignore@live.com',
#  '5980hallway@aol.com',
#  '5642changeable@yahoo.com',
#  '2295cyanic@compuserve.com',
#  '3895elver@yahoo.com',
#  '5255indissoluble@yahoo.com',
#  '3233cheer@live.com',
#  '8042tansy@aol.com',
#  '7272encumbrance@aol.com',
#  '2576stampede@aol.com',
#  '8209barbital@yahoo.com',
#  '5614scimitar@aol.com',
#  '2001furry@live.com',
#  '5455germane@live.com',
#  '8900tattle@compuserve.com',
#  '3713purine@yahoo.com',
#  '4942heroism@live.com',
#  '6029linebacker@aol.com',
#  '7676daguerreotype@yahoo.com',
#  '3926corpora@live.com',
#  '3427backstage@aol.com',
#  '8441nimble@live.com',
#  '3555pleurisy@live.com',
#  '6954monologist@yahoo.com',
#  '3349bryophyta@aol.com',
#  '2091divorce@yahoo.com',
#  '6785stalemate@aol.com',
#  '2344cryptography@aol.com',
#  '8700conform@aol.com',
#  '4184ethernet@aol.com',
#  '9853probationary@yahoo.com',
#  '6733notoriety@yahoo.com',
#  '3613lithospheric@aol.com',
#  '3415contact@aol.com',
#  '6395picosecond@live.com',
#  '1606turnabout@live.com',
#  '2802decorous@aol.com',
#  '7460semaphore@live.com',
#  '9243bane@compuserve.com',
#  '1524paramount@compuserve.com',
#  '1290pseudonym@yahoo.com',
#  '4811actual@yahoo.com',
#  '9209expiration@aol.com',
#  '6605maestro@aol.com',
#  '9174wand@aol.com',
#  '1611cesium@live.com',
#  '4925visitor@live.com',
#  '9068lumbermen@compuserve.com',
#  '7402signal@live.com',
#  '1454caprice@aol.com',
#  '6277hollowware@live.com',
#  '4999pitch@yahoo.com',
#  '6238intensify@yahoo.com',
#  '5578epsilon@yahoo.com',
#  '1909blew@compuserve.com',
#  '8044bob@yahoo.com',
#  '1347sunlight@compuserve.com',
#  '4175perch@compuserve.com',
#  '5313submitting@aol.com',
#  '6557discriminant@compuserve.com',
#  '5186short@aol.com',
#  '1675true@live.com',
#  '6498aqua@aol.com',
#  '8750hale@aol.com',
#  '2810respectful@live.com',
#  '7231admitted@aol.com',
#  '1865severalfold@yahoo.com',
#  '5775lampblack@aol.com',
#  '2205decide@live.com',
#  '1264huff@aol.com',
#  '5204cowmen@aol.com',
#  '3129animal@compuserve.com',
#  '1132insufficient@compuserve.com',
#  '6549recrudescent@yahoo.com',
#  '5441endgame@aol.com',
#  '1955crustacean@yahoo.com',
#  '9819postorder@yahoo.com',
#  '9742wattle@live.com',
#  '5970vein@compuserve.com',
#  '9966pellet@aol.com',
#  '7810echoes@aol.com',
#  '2383bottle@compuserve.com',
#  '2099defiant@compuserve.com',
#  '4409plaque@aol.com',
#  '9413flaw@yahoo.com',
#  '9508polymer@yahoo.com',
#  '2325blustery@aol.com',
#  '6881median@compuserve.com',
#  '6860small@aol.com',
#  '9541kidney@compuserve.com',
#  '9642legging@yahoo.com',
#  '4446product@yahoo.com',
#  '1956meadowsweet@yahoo.com',
#  '2633slob@aol.com',
#  '9741lackadaisic@yahoo.com',
#  '5224chest@compuserve.com',
#  '7203marshland@aol.com',
#  '3490flurry@aol.com',
#  '6976jock@aol.com',
#  '2061tagging@live.com',
#  '6033oriental@compuserve.com',
#  '8585commute@yahoo.com',
#  '1529duplicate@compuserve.com',
#  '4986nipple@compuserve.com',
#  '5276tuneful@compuserve.com',
#  '5938seek@compuserve.com',
#  '1763exciton@live.com',
#  '7585pottery@aol.com',
#  '2455producible@aol.com',
#  '7657fluoride@yahoo.com',
#  '1588spectacular@yahoo.com',
#  '9392spacious@compuserve.com',
#  '4200corpsmen@live.com',
#  '9588massif@aol.com',
#  '9708briar@live.com',
#  '6983abscond@aol.com',
#  '5653checklist@compuserve.com',
#  '2862prodigal@compuserve.com',
#  '7212ambition@compuserve.com',
#  '7538gluten@aol.com',
#  '4622minima@yahoo.com',
#  '1931indignant@yahoo.com',
#  '9577attend@live.com',
#  '1519syphilis@yahoo.com',
#  '3320squint@compuserve.com',
#  '7299foliate@live.com',
#  '7435heterogeneous@compuserve.com',
#  '3368catatonic@yahoo.com',
#  '4594concordant@compuserve.com',
#  '7793forfeit@live.com',
#  '3210tyrosine@yahoo.com',
#  '6639fusiform@aol.com',
#  '5306obese@live.com',
#  '8822her@yahoo.com',
#  '3713viscera@live.com',
#  '7486cerulean@aol.com',
#  '2354adrenalin@yahoo.com',
#  '1875anticonvulsant@live.com',
#  '5934incommensurable@live.com',
#  '3653turmeric@aol.com',
#  '7473warrior@yahoo.com',
#  '9068craven@live.com',
#  '8485bridesmaid@yahoo.com',
#  '3352expansive@live.com',
#  '9775illogic@compuserve.com',
#  '4374conflagrate@yahoo.com',
#  '2321igneous@compuserve.com',
#  '3689albeit@compuserve.com',
#  '1224governor@yahoo.com',
#  '3336acrimony@yahoo.com',
#  '9275photography@yahoo.com',
#  '4190catapult@yahoo.com',
#  '1062flotilla@live.com',
#  '1286entropy@live.com',
#  '1181asphalt@compuserve.com',
#  '3071refractory@live.com',
#  '7913hypophyseal@aol.com',
#  '3203hymnal@compuserve.com',
#  '7336quirk@yahoo.com',
#  '2819syllabus@yahoo.com',
#  '7070boogie@live.com',
#  '6199intern@live.com',
#  '4024artichoke@aol.com',
#  '7420example@live.com',
#  '3058desegregate@yahoo.com',
#  '2242crate@live.com',
#  '3338pennyroyal@compuserve.com',
#  '5498flowery@live.com',
#  '1040compound@aol.com',
#  '8012lunar@aol.com',
#  '1826hallelujah@compuserve.com',
#  '4762laureate@yahoo.com',
#  '7388sulfanilamide@compuserve.com',
#  '1773hip@aol.com',
#  '2549radium@live.com',
#  '4027ammonia@compuserve.com',
#  '1185unctuous@aol.com',
#  '6486carbonic@compuserve.com',
#  '9950perigee@aol.com',
#  '6776shrewd@aol.com',
#  '8569sunrise@aol.com',
#  '6197ideal@aol.com',
#  '4664blissful@aol.com',
#  '6723maternal@compuserve.com',
#  '6691standpoint@aol.com',
#  '8031business@yahoo.com',
#  '4756pledge@yahoo.com',
#  '8130stadia@yahoo.com',
#  '8813appellate@compuserve.com',
#  '3966malice@live.com',
#  '9046posterior@aol.com',
#  '1517trial@compuserve.com',
#  '3624declare@compuserve.com',
#  '8413innuendo@yahoo.com',
#  '8601halma@compuserve.com',
#  '8552lighthouse@compuserve.com',
#  '1054sugary@aol.com',
#  '5975commonality@yahoo.com',
#  '8325propelling@aol.com',
#  '4484amoeba@yahoo.com',
#  '9203paintbrush@live.com',
#  '9374pull@yahoo.com',
#  '8661cerebellum@compuserve.com',
#  '2822bronchiole@aol.com',
#  '3852grocer@compuserve.com',
#  '1345perfect@compuserve.com',
#  '6121crosscut@live.com',
#  '2213tenspot@compuserve.com',
#  '3661criss@live.com',
#  '7311expectorant@compuserve.com',
#  '2695preparation@live.com',
#  '3774disruption@compuserve.com',
#  '5066starve@aol.com',
#  '1269respiratory@yahoo.com',
#  '1544bishopric@aol.com',
#  '4434applicable@yahoo.com',
#  '7194waterfowl@live.com',
#  '3075velocity@aol.com',
#  '7859biz@aol.com',
#  '6710fist@live.com',
#  '5052whorl@yahoo.com',
#  '3239lox@yahoo.com',
#  '8170cartography@compuserve.com',
#  '3531rectifier@yahoo.com',
#  '1887potpourri@compuserve.com',
#  '9064affiliate@aol.com',
#  '9103improvise@live.com',
#  '3572rebuke@aol.com',
#  '3786henpeck@aol.com',
#  '8179indefensible@yahoo.com',
#  '7942knuckleball@live.com',
#  '4514necromantic@compuserve.com',
#  '2501blight@aol.com',
#  '4489adventurous@yahoo.com',
#  '4252chorus@live.com',
#  '9000jangle@compuserve.com',
#  '7592glitch@compuserve.com',
#  '7747periphrastic@aol.com',
#  '3416glissade@compuserve.com',
#  '9276commonality@compuserve.com',
#  '6505showpiece@yahoo.com',
#  '2430doorman@aol.com',
#  '6741harmonic@yahoo.com',
#  '1776contiguity@compuserve.com',
#  '2681administrate@aol.com',
#  '8095flak@yahoo.com',
#  '4539fluffy@yahoo.com',
#  '8413kick@aol.com',
#  '7526dye@yahoo.com',
#  '6097path@compuserve.com',
#  '8832familial@yahoo.com',
#  '1391rod@yahoo.com',
#  '7674interior@compuserve.com',
#  '2021canny@aol.com',
#  '6843effort@compuserve.com',
#  '2836sportswriting@aol.com',
#  '1873antonym@compuserve.com',
#  '7630macromolecular@live.com',
#  '6440swam@live.com',
#  '8018foible@yahoo.com',
#  '5494lacerate@compuserve.com',
#  '3928kilohm@yahoo.com',
#  '8138person@aol.com',
#  '4112storehouse@compuserve.com',
#  '8886bock@yahoo.com',
#  '7160puddly@live.com',
#  '3867hazard@live.com',
#  '7097courtesy@yahoo.com',
#  '7763acidulate@live.com',
#  '8655mosaic@live.com',
#  '2112dizzy@compuserve.com',
#  '4564hosiery@live.com',
#  '6738tide@compuserve.com',
#  '8313metamorphism@yahoo.com',
#  '2304dovekie@compuserve.com',
#  '3156salvo@aol.com',
#  '1331spend@aol.com',
#  '4995gem@compuserve.com',
#  '4663catchword@compuserve.com',
#  '8144brakemen@yahoo.com',
#  '1217incessant@aol.com',
#  '9514whole@yahoo.com',
#  '7570andesite@yahoo.com',
#  '2002turn@live.com',
#  '9824shire@aol.com',
#  '4455heck@aol.com',
#  '8055causate@aol.com',
#  '5409large@live.com',
#  '1423appropriable@live.com',
#  '8194workplace@compuserve.com',
#  '1698broil@compuserve.com',
#  '5822taper@compuserve.com',
#  '4625sup@aol.com',
#  '4073think@yahoo.com',
#  '7701counterproductive@live.com',
#  '8985geochemical@compuserve.com',
#  '9872runty@compuserve.com',
#  '3747bratwurst@yahoo.com',
#  '6609snap@compuserve.com',
#  '4002omnivore@yahoo.com',
#  '4793eliminate@aol.com',
#  '8551visage@yahoo.com']

# %% [markdown]
# ### Pull all the names from the data variable

# %%
names = re.findall('\s+Name:\s+([A-Z]{1}[a-z]+\s+[A-Z]{1}[a-z]+)',data)
names
# Out:
# ['Knossos Kuwait',
#  'Bruno Edgerton',
#  'Berkowitz Palomar',
#  'Abe Aden',
#  'Angles Quichua',
#  'Rosa Agee',
#  'Dorcas Hebraic',
#  'Brahmaputra Seton',
#  'Nicodemus Jon',
#  'Cuba Guam',
#  'Bessel Hadley',
#  'Laredo Dorset',
#  'Twombly Lombardy',
#  'Banach Jed',
#  'Thayer Timex',
#  'Duluth Shakespearean',
#  'Fulbright Nicholas',
#  'Melissa Leonardo',
#  'Cavendish Agamemnon',
#  'Burnett Trichinella',
#  'Witt Kessler',
#  'Oswald Mooney',
#  'Mercator Hansen',
#  'Glasgow Motorola',
#  'Wesley Otis',
#  'Barrington Borealis',
#  'Sherlock Baxter',
#  'Thimbu Nazareth',
#  'Loki Atlanta',
#  'Aleck Brittany',
#  'Fletcher Azerbaijan',
#  'Vermont Philadelphia',
#  'Acadia Pythagorean',
#  'Kentucky Ferreira',
#  'Lithuania Taylor',
#  'Prof Rochester',
#  'Adolph Hurd',
#  'Malay Schroedinger',
#  'Brussels Carlton',
#  'Justine Kamchatka',
#  'Lockian Loren',
#  'Chapman Vietnam',
#  'Fuji Wabash',
#  'Jules Dnieper',
#  'Sanford Wahl',
#  'Crockett Aeneid',
#  'Keynes Estes',
#  'Martinique Monrovia',
#  'Conrad Monday',
#  'Nguyen Lawson',
#  'Hispanic Charlotte',
#  'Freetown Triceratops',
#  'Cromwell Byrne',
#  'Chinatown Quichua',
#  'Jamestown Naomi',
#  'Iberia Levis',
#  'Hoyt Texaco',
#  'Ifni Caputo',
#  'Roger Johansen',
#  'Samoa Elaine',
#  'Swanson Galapagos',
#  'Galen Pauline',
#  'Orin Dortmund',
#  'Dianne Miocene',
#  'Transylvania Midwest',
#  'Woodstock Hayes',
#  'Quebec Nile',
#  'Selkirk Stafford',
#  'Hildebrand Cervantes',
#  'Burmese Vladivostok',
#  'Shapiro Fomalhaut',
#  'Levin Monterey',
#  'Bailey Coors',
#  'Kochab Lindquist',
#  'Elmsford Mahayanist',
#  'Tuttle Hendrick',
#  'Lemuel Candide',
#  'Fletcher Shylock',
#  'Sternberg Iberia',
#  'Alexandre Waals',
#  'Mawr Fitzroy',
#  'Floridian Cyrus',
#  'Faber Russell',
#  'Marrietta Jonathan',
#  'Olaf Christy',
#  'Sepoy India',
#  'Brock Frankel',
#  'Machiavelli Coffman',
#  'Fresnel Allstate',
#  'Honshu Cambodia',
#  'Corinth Manchuria',
#  'Washburn Mozart',
#  'Sacramento Jeremy',
#  'Bible Corbett',
#  'Kruger Cassius',
#  'Blackwell Pickering',
#  'Welch Wesleyan',
#  'Wagner Morgan',
#  'Majorca Christie',
#  'Hellespont Cyclades',
#  'Faulkner Brainard',
#  'Cosgrove Palmyra',
#  'Julie Irma',
#  'Saturday Linus',
#  'Zealand Borg',
#  'Theresa Davies',
#  'Emerson Valletta',
#  'Sumter Wiley',
#  'Romulus Kankakee',
#  'Hadley Bose',
#  'Edison Johanna',
#  'Cummins Weldon',
#  'Transite Asuncion',
#  'Ilona Dietrich',
#  'Winnipeg Mc',
#  'Toronto Huntley',
#  'Univac Suez',
#  'Saturnalia Dnieper',
#  'Siegfried Dearborn',
#  'Minotaur Simmons',
#  'Fujitsu Mauricio',
#  'Araby Balzac',
#  'Laurentian Corvallis',
#  'Ingersoll Cushing',
#  'Methuselah Switzerland',
#  'Burnside Blanche',
#  'Carib Madison',
#  'Bucknell Buena',
#  'Fuchs Ella',
#  'Istanbul Norris',
#  'Millard Connors',
#  'Spaniard Wilhelmina',
#  'Anglo Germantown',
#  'Fischbein Stahl',
#  'Neapolitan Araby',
#  'Hewett Zellerbach',
#  'Huntington Emil',
#  'Linus Andean',
#  'Eugene Catalina',
#  'Australis Hettie',
#  'Hayes Lippincott',
#  'Durham Coulter',
#  'Blvd Melvin',
#  'Buxtehude Passover',
#  'Minoan Charon',
#  'Leonard Carnegie',
#  'Ariadne Georgetown',
#  'Lancelot Orphic',
#  'Emory Michelin',
#  'Brunswick Tientsin',
#  'Groton Hadamard',
#  'Daley Becky',
#  'Muriel Daedalus',
#  'Cluj Rowley',
#  'Catskill Tyler',
#  'Ramsey Gustafson',
#  'Whelan Zorn',
#  'Pegasus Kieffer',
#  'Semitic Polynesia',
#  'Dobbs Dorothy',
#  'Pleiades Marion',
#  'Laurent Dar',
#  'Boise Georgia',
#  'Congo Muscat',
#  'Arlen Jugoslavia',
#  'Rowe Hamlin',
#  'Coates Stygian',
#  'Wightman Spaniard',
#  'Sarasota Goldstine',
#  'Narragansett Knowles',
#  'Pyle Huntsville',
#  'Vaudois Aldrich',
#  'Chungking Coddington',
#  'Priestley Hermite',
#  'Alcmena Antarctica',
#  'Schlitz Gladstone',
#  'Byron Ito',
#  'Ann Snyder',
#  'Pontiac Weierstrass',
#  'Spencerian Mc',
#  'Agamemnon Seward',
#  'Afrikaans Greenbelt',
#  'Grady Garcia',
#  'Auerbach Fiberglas',
#  'Hitler Orono',
#  'Hausa Majorca',
#  'Menorca Griswold',
#  'Smithson Sadler',
#  'Salem Dido',
#  'Tuscaloosa Fallopian',
#  'Portsmouth Winthrop',
#  'Whitney Hitler',
#  'Copernicus Buddhism',
#  'Abbott Dubhe',
#  'Rensselaer Hastings',
#  'Maloney Canada',
#  'Dan Neptune',
#  'Borg Barcelona',
#  'Boswell Chautauqua',
#  'Guyana Sam',
#  'Mavis Hayden',
#  'Netherlands Jeff',
#  'Beethoven Alicia',
#  'Ganymede Weller',
#  'Studebaker Salesian',
#  'Bern Methuselah',
#  'Beresford Andalusia',
#  'Moresby Wier',
#  'Isaac Ilyushin',
#  'Jovanovich Liz',
#  'Parmesan Herbert',
#  'Cobb Seaborg',
#  'Asher Multics',
#  'Gunderson Fernando',
#  'Hanford Farley',
#  'Cuba Oxonian',
#  'Kiewit Selectric',
#  'Queensland Oresteia',
#  'Hodgkin Zulu',
#  'Shelby Gustavus',
#  'Lockwood Rosa',
#  'Mirfak Caleb',
#  'Wolff Penh',
#  'Alexis Cody',
#  'Farrell Francoise',
#  'Aeschylus Rosenberg',
#  'Arcadia Laban',
#  'Batavia Sicily',
#  'Carmichael Iverson',
#  'Baldwin Chinatown',
#  'Ferber Claude',
#  'Kepler Eros',
#  'Kiev Quirinal',
#  'Edward Signor',
#  'Bloomfield Gottfried',
#  'Bulgaria Arianism',
#  'Galatea Portuguese',
#  'Falkland Nubia',
#  'Twombly Frenchman',
#  'Pinsky Bengal',
#  'Bohemia Khrushchev',
#  'Callaghan Newport',
#  'Campbell Franz',
#  'Brazilian Appleby',
#  'Gershwin Fayetteville',
#  'Andromeda Buchanan',
#  'Fitzgerald Stuart',
#  'Ross Djakarta',
#  'Waller Poe',
#  'Anabaptist Millard',
#  'Jung Boswell',
#  'Galway Egyptology',
#  'Harlem Mayo',
#  'Healy Bodleian',
#  'Oscar Newtonian',
#  'Orlando Nazareth',
#  'Ariadne Switzerland',
#  'Mafioso Hesperus',
#  'Miami Exeter',
#  'Chao Caroline',
#  'Sargent Burnett',
#  'Laurentian Sardinia',
#  'Kenya Ripley',
#  'Sri Pritchard',
#  'Baltimorean Quantico',
#  'Alvarez Josef',
#  'Barton Edgar',
#  'Fleming Gorky',
#  'Horace California',
#  'Shenandoah Zulu',
#  'Chinaman French',
#  'Wesleyan Potomac',
#  'Beverly Tina',
#  'Conrad Dostoevsky',
#  'Carlton Grover',
#  'Aeschylus Bentham',
#  'Benny Aegean',
#  'Hippocrates Nestor',
#  'Stygian Washington',
#  'Geraldine Huxley',
#  'Constantine Bamako',
#  'Cramer Wilkinson',
#  'Ackley Kabuki',
#  'Hadley Pinsky',
#  'Chester Araby',
#  'Ephraim Fletcher',
#  'Foxhall Ekstrom',
#  'Runyon Chinese',
#  'Chalmers Sherwood',
#  'Englander Gaspee',
#  'Saskatoon Chimique',
#  'Seychelle Antoinette',
#  'Icarus Newtonian',
#  'Orpheus Patsy',
#  'Connie Charta',
#  'Dirac Delmarva',
#  'Semite Yonkers',
#  'Callahan Chicano',
#  'Hendrickson Antoine',
#  'Rochester Palatine',
#  'Bali Virgil',
#  'Cambrian Genesco',
#  'Moghul Colby',
#  'Macedon Selfridge',
#  'Plexiglas Hutchison',
#  'Shoshone Shepard',
#  'Dis Casey',
#  'Claude Perry',
#  'Istvan Hillcrest',
#  'Ottawa Nabisco',
#  'Inman Lufthansa',
#  'Bartlett Veneto',
#  'Leyden Delft',
#  'Trumbull Mira',
#  'Shakespearian Kentucky',
#  'Lancashire Mc',
#  'Boltzmann Nottingham',
#  'Macassar Linton',
#  'Gaylord Farkas',
#  'Middletown Damon',
#  'Caracas Livingston',
#  'Lyman Buchenwald',
#  'Barlow Sadie',
#  'Hepburn Atkins',
#  'Parr Farley',
#  'Kowloon Carolyn',
#  'Jan Witt',
#  'Lizzie Porte',
#  'Israelite Fizeau',
#  'Moiseyev Koran',
#  'Nabisco Malcolm',
#  'Ella Hadamard',
#  'Braun Karachi',
#  'Falmouth Brigham',
#  'Coffey Bryant',
#  'Collier Adair',
#  'Thursday Paula',
#  'Marshall Cassiopeia',
#  'Youngstown Copenhagen',
#  'Florence Hanson',
#  'Galveston Kessler',
#  'Ludwig Saturnalia',
#  'Waldron Jason',
#  'Whalen Chaucer',
#  'Olympic Rousseau',
#  'Lundquist Douglass',
#  'Fairchild Urbana',
#  'Auckland Sudanese',
#  'Jonathan British',
#  'Andromache Barry',
#  'Abner Gerard',
#  'Pelham Ghana',
#  'Driscoll Griswold',
#  'Cosgrove Seaborg',
#  'Guardia Chopin',
#  'Honduras Sequoia',
#  'Blomquist Harley',
#  'Varitype Kennan',
#  'Sarah Schofield',
#  'Nazi Olsen',
#  'Lise Birmingham',
#  'Rosenthal Duane',
#  'Fayette Styrofoam',
#  'Brendan Caputo',
#  'Phillip Laurent',
#  'Egyptian Corinthian',
#  'Boreas Whitman',
#  'Wei Atlantis',
#  'Danny Hiawatha',
#  'Bologna Norris',
#  'Renault Colby',
#  'Howard Cheney',
#  'Baird Dietz',
#  'Huston Manchester',
#  'Ely Furman',
#  'Hera Coleman',
#  'Boeing Boyle',
#  'Dow Burundi',
#  'Calvin Selkirk',
#  'Burke Darrell',
#  'Debussy Mardi',
#  'Estella Marlene',
#  'Fontainebleau Eugenia',
#  'Angelo Logan',
#  'Hamburg Hanlon',
#  'Northampton Haines',
#  'Kashmir Shulman',
#  'Lucian Brewster',
#  'Lawrence Blackstone',
#  'Salvatore Lissajous',
#  'Kimberly Rosenblum',
#  'Corinth Bonaventure',
#  'Mogadiscio Carlyle',
#  'Theodore Ovid',
#  'Chaplin Dionysian',
#  'Potomac Wasserman',
#  'Shockley Vicky',
#  'Israelite Angus',
#  'Hesperus Maloney',
#  'St Mac',
#  'Galilean Johanna',
#  'Arabia Kieffer',
#  'Stan Grendel',
#  'Percy Giuliano',
#  'Horatio Garry',
#  'Perseus Scheherazade',
#  'Eliot Punjabi',
#  'Orestes Doppler',
#  'Draconian Elliott',
#  'Timex Arizona',
#  'Darwinian Gwyn',
#  'Jefferson Quezon',
#  'Susanne Jansenist',
#  'Sidney Christine',
#  'Gwen Judy',
#  'Knowlton Persia',
#  'Smucker Bible',
#  'Houdaille Beebe',
#  'Arrhenius Talmud',
#  'Emil Hatteras',
#  'Caesarian Horace',
#  'Rudolf Stokes',
#  'Mullen Flanagan',
#  'Giles Svetlana',
#  'Dorchester Marty',
#  'Gallup Noll',
#  'Orr Switzerland',
#  'Laredo Burr',
#  'Farnsworth Prescott',
#  'Worcestershire Rankine',
#  'Pl Montrachet',
#  'Frenchmen Thelma',
#  'Schumacher Fuchsia',
#  'Manchuria Delphi',
#  'Avon Wylie',
#  'Jakarta Gannett',
#  'Celebes Sisyphus',
#  'Hera Lancashire',
#  'Swarthout Ruanda',
#  'Litton Cypriot',
#  'Chicagoan Frankel',
#  'Rosalie Olav',
#  'Burgundian Kitakyushu',
#  'Appian Comanche',
#  'Champlain Emanuel',
#  'Whitney Cambrian',
#  'Caesar Johannes',
#  'Kingsley Arab',
#  'Hughes Nicholson',
#  'Beebe Shmuel',
#  'Elkhart Pravda',
#  'Bangor Boise',
#  'Virginia Washburn',
#  'Saratoga Cincinnati',
#  'Politburo Parke',
#  'Karen Elliott',
#  'Cypriot Plexiglas',
#  'Andy Jefferson',
#  'Lucia Wilkins',
#  'Carlin Cargill',
#  'Winchester Rome',
#  'Apollonian Graff',
#  'Mahayanist Donovan',
#  'Gouda Kirov',
#  'Shu Quichua',
#  'Borroughs Kline',
#  'Hopkins Mabel',
#  'Bamako Castro',
#  'Burgundy Lateran',
#  'Puerto Pyle',
#  'Natalie Bedford',
#  'Evans Emerson',
#  'Verdi Ballard',
#  'Darius Finnegan',
#  'Enid Portuguese',
#  'Agnes Procyon',
#  'Krakow Boeing',
#  'Conrad Anthony',
#  'Hewett Watanabe',
#  'Guenther Bundestag',
#  'Pulaski Reagan',
#  'Wotan Chinook',
#  'Felice Lincoln',
#  'Christopher Davis',
#  'Bangor Melbourne',
#  'Carmen Polyphemus',
#  'Frigga Moore',
#  'Stratton Chablis',
#  'Gail Procter',
#  'Rd Boucher',
#  'Moresby Bert',
#  'Baku Chisholm',
#  'Pembroke Mc',
#  'Hoffman Byrne',
#  'Ababa Schiller',
#  'Michele Schoenberg',
#  'Reinhold Hercules',
#  'Newell Jewett',
#  'Erato Mel',
#  'Wittgenstein Trichinella',
#  'Hertzog Wilbur',
#  'Luzon Cromwell',
#  'Goldwater Marcel',
#  'Mickelson Beltsville',
#  'Lobelia Marcus',
#  'Falstaff Canadian',
#  'Ulan Albrecht',
#  'Faust Alexandre',
#  'Bleeker Merrimack',
#  'Irishmen Pergamon',
#  'Cranford Garvey',
#  'Evanston Dee',
#  'Bechtel Ecuador',
#  'Aarhus Belgian',
#  'Mycenae Amman',
#  'Shelley Yaqui',
#  'Virginia Charles',
#  'Rex Muscovite',
#  'Laocoon Mateo',
#  'Lafayette Watergate',
#  'Poe Isaacson',
#  'Massey Ilona',
#  'Blumenthal Bausch',
#  'Ophiucus Adelaide',
#  'Adrienne Byzantium',
#  'Cowan Cameroon',
#  'Israelite Oshkosh',
#  'Formosa Telex',
#  'Carbone Sadler',
#  'Durham Andersen',
#  'Matsumoto Mayflower',
#  'Battelle Annale',
#  'Fayette Ukraine',
#  'Osiris Lithuania',
#  'Sidney Apollo',
#  'Barton Churchillian',
#  'Lorinda Poincare',
#  'Steuben Bernice',
#  'Disney Madison',
#  'Amos Mathewson',
#  'Faulkner Wheller',
#  'Bantu Garcia',
#  'Braille Antietam',
#  'Cypriot Bruegel',
#  'Smithfield Faustian',
#  'Watergate Connors',
#  'Dorchester Endicott',
#  'Wyeth Kabuki',
#  'Pericles Shylock',
#  'Maier Jansenist',
#  'Yakima Hermes',
#  'Friday Vietnam',
#  'Barrymore Sumter',
#  'Alcestis Jupiter',
#  'Zomba Corp',
#  'Tantalus Charlottesville',
#  'Buick Falmouth',
#  'Sherwood Bologna',
#  'Lancaster Leone',
#  'Mudd Antoine',
#  'Doppler Teutonic',
#  'Muong Czechoslovakia',
#  'Pinsky Nairobi',
#  'Nairobi Honda',
#  'Jacques Uris',
#  'Theresa Slavic',
#  'Negroes Montmartre',
#  'Bucknell Islamic',
#  'Brock Arrhenius',
#  'Cathy Baptist',
#  'Ellison Claus',
#  'Mona Feldman',
#  'Melissa Frick',
#  'Cajun Taylor',
#  'Jorgenson Signora',
#  'Perry Jose',
#  'Parke Candide',
#  'Len Perseid',
#  'Hokan Syria',
#  'Stirling Ellis',
#  'Krebs February',
#  'Bernoulli Tacitus',
#  'Rotarian Johann',
#  'Babylon Hanoverian',
#  'Duane Bodleian',
#  'Morton Weston',
#  'Drury Delmarva',
#  'Hanoi Seaborg',
#  'Casey Stacy',
#  'Atwood Florence',
#  'Dominic Friedrich',
#  'Angelina Brazil',
#  'Tammany Liggett',
#  'Amman Calvin',
#  'Pakistani Lyle',
#  'Kirby Maltese',
#  'Melissa Juneau',
#  'Burr Brussels',
#  'Colombia Cyprian',
#  'Hyades Gandhi',
#  'Willie Celsius',
#  'Acton Annie',
#  'Crimea Camino',
#  'Ronnie Notre',
#  'Caine Seth',
#  'Nevada Neva',
#  'Honshu Nineveh',
#  'Lynn Valkyrie',
#  'Holm Muenster',
#  'Hungarian Valerie',
#  'Prague Arizona',
#  'Pancho Hawaii',
#  'Odessa Strom',
#  'Isabella Vicksburg',
#  'Mormon Peking',
#  'Masonite Verona',
#  'Elizabeth Bulgaria',
#  'Mawr Tunis',
#  'Waterhouse Tarbell',
#  'Hebrides Jacky',
#  'Guinevere Keenan',
#  'Berkshire Davies',
#  'Latvia Cohen',
#  'Reinhold Rwanda',
#  'Southampton Middlebury',
#  'Springfield Diophantine',
#  'Shakespeare Bayda',
#  'Balboa Moldavia',
#  'Noah Beecham',
#  'Andrei Andean',
#  'Stratton Kalmuk',
#  'Wilhelm Amsterdam',
#  'Pappas Estonia',
#  'Arabic Swaziland',
#  'Sao Celt',
#  'Chimique Bavaria',
#  'Bremen Gillette',
#  'Westchester Tokyo',
#  'Americana Gimbel',
#  'Christian Uruguay',
#  'Godwin Wabash',
#  'Gleason Lagrangian',
#  'Topeka Haugen',
#  'Jacobson Faustus',
#  'Johnsen Mc',
#  'Celanese Bradbury',
#  'Pappas Dutton',
#  'Sagittarius Andrea',
#  'Camino Arapaho',
#  'Berniece Kovacs',
#  'Wisconsin Mc',
#  'Catskill Dunkirk',
#  'Magellanic Swanson',
#  'Rockies Godwin',
#  'Ophiucus Cherokee',
#  'Varitype Christenson',
#  'Yves Kirkland',
#  'Dwight Kansas',
#  'Chile Joan',
#  'Garvey Warsaw',
#  'Frigga Foote',
#  'Cunard Zachary',
#  'Halverson Greene',
#  'Dionysus Charlotte',
#  'Levitt Diebold',
#  'Olivier Conner',
#  'Sterno Walton',
#  'Strom Forsythe',
#  'Peugeot Schuyler',
#  'Whelan Thayer',
#  'Caruso Parmesan',
#  'Tacitus Felicia',
#  'Leonardo Paulus',
#  'Krause Pam',
#  'Cincinnati Bootes',
#  'Dunkirk Freetown',
#  'Alex Tudor',
#  'Torrance Perkins',
#  'Gaithersburg Groton',
#  'Honshu Betelgeuse',
#  'Hiawatha Johnsen',
#  'Halsey Fermat',
#  'Charlie Christiana',
#  'Gould Oscar',
#  'Dublin Friedman',
#  'Bowdoin Fontaine',
#  'Bangladesh Rafael',
#  'Thorpe Aztec',
#  'Houdini Minsk',
#  'Sirius Shapiro',
#  'Chicano Sykes',
#  'Brainard Harold',
#  'Matilda Meistersinger',
#  'Dnieper Karl',
#  'Baghdad Caracas']

# %% [markdown]
# ### Pull all the passwords from the data variable

# %%
pas = re.findall('\s+([0-9]{2}[a-z]+[0-9]{3}[a-z]*)',data)
pas
# Out:
# ['34drizzle874camembert',
#  '88phylogeny225eumenides',
#  '52cursive336goff',
#  '82ephemeris546emil',
#  '99platelet487dorado',
#  '92dolly708martinson',
#  '64convert222fresnel',
#  '18usurious502bmw',
#  '13figure332chadwick',
#  '51certitude305mysore',
#  '86hypotheses299steuben',
#  '84jilt423fourier',
#  '61dagger447eulerian',
#  '49conjecture815knutson',
#  '87scripture832guthrie',
#  '46foursquare282wronskian',
#  '68mummy464bolshevist',
#  '41attorney179martinez',
#  '81bevel200brisbane',
#  '42frescoes731meg',
#  '66debauchery305luzon',
#  '35chalky237nobel',
#  '59agog255evanston',
#  '48pomology548huston',
#  '79catch473terpsichore',
#  '30ameliorate413senora',
#  '20collapse139bowditch',
#  '36scarce418cajun',
#  '88supervene853warburton',
#  '86scope683nicholson',
#  '40courage517sebastian',
#  '54baronet441nm',
#  '36itself201sextans',
#  '80cockleshell732brenda',
#  '92ferruginous697pyle',
#  '79swim582dalhousie',
#  '81vase537stamford',
#  '79blare945neil',
#  '60argillaceous686lomb',
#  '68urbane775carolina',
#  '28cheery398muscovy',
#  '85gazelle184calvin',
#  '78crewcut443linotype',
#  '91roughen731guiana',
#  '90obtrude942flagstaff',
#  '62gladiator129huxtable',
#  '65mercantile250sault',
#  '24psyche147parkinson',
#  '94afterbirth427serpens',
#  '23bureaucratic935lafayette',
#  '42bitterroot418vinson',
#  '84cranium392zanzibar',
#  '66bewitch352diana',
#  '50rout771honduras',
#  '26dialysis333jimmie',
#  '65pizza293jerome',
#  '25appreciate234sturm',
#  '69chomp264dunlop',
#  '50diagnostician596pedro',
#  '45ibid859boyle',
#  '40decreeing278alice',
#  '73orthopedic330andromeda',
#  '26may821albert',
#  '79microscopy166alexander',
#  '40blab159berwick',
#  '24millinery517gruyere',
#  '89baggage635brazzaville',
#  '85tinker587assam',
#  '96ribosome868nicosia',
#  '12stamen996cruickshank',
#  '89investor754milwaukee',
#  '57occidental422runge',
#  '62anomie891procter',
#  '76grovel916pinehurst',
#  '11doze966carolingian',
#  '99pogo695elkhart',
#  '84respiration408johannes',
#  '39pronunciation771felix',
#  '66discreet618arapaho',
#  '46gusset188moline',
#  '44edgy498portia',
#  '29leisure436krueger',
#  '19incondensable205melanie',
#  '37kinsman313guenther',
#  '74paddock611peabody',
#  '68brewery945yonkers',
#  '69airlift516marlboro',
#  '81sunset808uganda',
#  '77cube800dunedin',
#  '11neuromuscular398daedalus',
#  '52alphabetic679benelux',
#  '40grievous653linus',
#  '69cloy263moriarty',
#  '91woebegone293ptolemaic',
#  '79obscure154araby',
#  '99warmonger726pericles',
#  '54allude962estella',
#  '99grasshopper339serpens',
#  '15surprise881mayfair',
#  '61quadripartite646winnipesaukee',
#  '91bracket550walton',
#  '29tercel251dora',
#  '20mylar476harlan',
#  '81radioastronomy774mobil',
#  '23hypothermia548palo',
#  '56hologram253ragusan',
#  '12selenate533gruyere',
#  '91traitor227chao',
#  '84mute441kashmir',
#  '49inviolable801dixon',
#  '43installation514hess',
#  '72runaway269buddhism',
#  '27traipse221macbeth',
#  '95snail824o',
#  '94equipping333ptolemy',
#  '45vulture611mahayanist',
#  '52esprit197bridget',
#  '57icon781zanzibar',
#  '81arduous570erskine',
#  '17knelt741peruvian',
#  '26raj187barclay',
#  '69ceil333rene',
#  '63hay806fitzroy',
#  '20creaky791davis',
#  '33recompense173bruegel',
#  '19forgo200forsythe',
#  '79compatriot475leyden',
#  '72allele854beloit',
#  '25halite945heuser',
#  '77lability630lansing',
#  '78quasar762boyce',
#  '35septillion576miles',
#  '88spite118chaucer',
#  '85nectary520egyptology',
#  '93bah396bulgaria',
#  '44oriole888abelian',
#  '95ceremonious710a',
#  '90panorama404furman',
#  '49indisposition505coors',
#  '74eternity878volta',
#  '65improper588angola',
#  '26curmudgeon948clarendon',
#  '29rebuttal666vancouver',
#  '41peril175myers',
#  '95personify457acton',
#  '27asteroid481tuesday',
#  '64appraise970chesterton',
#  '72bombard191aesop',
#  '78awash303ruben',
#  '59thereto340cochrane',
#  '33leaflet423johnsen',
#  '55sandhill546phobos',
#  '16penthouse351ralph',
#  '35nest580livingston',
#  '74forest223papua',
#  '51enzymatic142tibetan',
#  '95gorilla426wabash',
#  '69prodigious886glendale',
#  '81bouillon321alcmena',
#  '10element295patagonia',
#  '74mutineer150chad',
#  '30repelling638clarendon',
#  '32indiscriminate798derbyshire',
#  '18fauna751jaeger',
#  '16alongside276irene',
#  '53pigeonberry542caesarian',
#  '69indigestion856bismarck',
#  '16emphasis377teddy',
#  '18raincoat954danielson',
#  '92meteorology967carla',
#  '40teamster996yokuts',
#  '51abeyant467mcguire',
#  '39herself849patti',
#  '21vivace389sri',
#  '66alfalfa975riemann',
#  '71seltzer877terre',
#  '19transpiration728nichols',
#  '26thorax955lenore',
#  '29locoweed957appleton',
#  '61murder216elisha',
#  '36expressible432beckman',
#  '88tenure485hobart',
#  '66ecstasy499haitian',
#  '69skullcap341howell',
#  '56ordain827congolese',
#  '33clannish293burton',
#  '14countdown326dennis',
#  '42formulaic671saturn',
#  '42urinate845pinsky',
#  '45arccos628heraclitus',
#  '65scorecard922nanette',
#  '43fathom147pavlov',
#  '65emaciate151libra',
#  '97vineyard845procyon',
#  '79forgo606dostoevsky',
#  '31egg883buckley',
#  '68chestnut816mcdermott',
#  '37dereference198ohio',
#  '54sonic655guardia',
#  '66plume742healy',
#  '75protestant356antoinette',
#  '19sphinx669cassiopeia',
#  '79hole919ekstrom',
#  '14fleeing299prussia',
#  '17newspapermen999dusenberg',
#  '70ember468clotho',
#  '88prohibitory769norman',
#  '51inflater802mccluskey',
#  '22fulfill540portugal',
#  '75approach282cornelius',
#  '52secular285bette',
#  '21apoplectic112shreveport',
#  '93forklift651hungary',
#  '79intuitive993styrofoam',
#  '15wrongdoer636andean',
#  '51beforehand414whitman',
#  '24daybed467yorktown',
#  '12floruit964mcintyre',
#  '40oldster520hadrian',
#  '63minestrone866salish',
#  '46symbiote710tex',
#  '76taxpaying443istvan',
#  '95limpkin585eileen',
#  '89viscometer657artie',
#  '33persevere116rigel',
#  '79sardine669gwen',
#  '68pavilion330hegelian',
#  '96portmanteau643salisbury',
#  '88signal158gloucester',
#  '27obtuse170geraldine',
#  '92heal100precambrian',
#  '31bonito827euridyce',
#  '28greenery195tenneco',
#  '42bryophyte373sherwin',
#  '53byline183fabian',
#  '37sane384bakhtiari',
#  '13introversion550wyoming',
#  '90truculent237hutchinson',
#  '91doubleton229heidelberg',
#  '22inhibit118glenn',
#  '28withstood601se',
#  '12osier969churchillian',
#  '32metabolite481sinclair',
#  '67glorious683pittston',
#  '94what663gestapo',
#  '30cargo111arden',
#  '17ruddy268egypt',
#  '99fad398genoa',
#  '92begging635luzon',
#  '63cordage331justinian',
#  '26herringbone811margo',
#  '44crap347fairfield',
#  '57entomology764haag',
#  '92decompose863asia',
#  '84bianco421boswell',
#  '64devotion181thomistic',
#  '26liquid452procrustes',
#  '18syndrome155agricola',
#  '53flam926chimique',
#  '78schoolgirlish366betsy',
#  '92hypotheses184kevin',
#  '37tripe262textron',
#  '92childbirth519hal',
#  '43worshipful859baja',
#  '12antebellum999mueller',
#  '61doddering518bengali',
#  '51presumptive172bertram',
#  '96browse688gsa',
#  '43guerrilla518parrish',
#  '11dill717gustave',
#  '27bicarbonate863jeremiah',
#  '94insult652irvine',
#  '76locale805carlsbad',
#  '19concerto265carlin',
#  '21loud260judaica',
#  '34aphid563albrecht',
#  '20carpetbagger552forsythe',
#  '66phenyl420asia',
#  '43vellum949ir',
#  '85deficit102horace',
#  '29limelight228gilead',
#  '93indigestion874joanne',
#  '78shown925mph',
#  '41chip332wilhelm',
#  '12searchlight752gould',
#  '59except918canadian',
#  '99receptor867regina',
#  '77duplex330smythe',
#  '52seismograph826latvia',
#  '54concord618johnston',
#  '54revenge233puritan',
#  '31person918bergland',
#  '38normalcy513charlemagne',
#  '43arm695november',
#  '35stole964triassic',
#  '41devout858cern',
#  '38shortage420heine',
#  '27waxwing159toronto',
#  '29formulaic745appleby',
#  '80newborn381bosporus',
#  '42clockwatcher302joyce',
#  '47malaria242faa',
#  '63tropospheric668paterson',
#  '31plenipotentiary578paz',
#  '31persecute407etruscan',
#  '97culpa993grendel',
#  '56beguile502midwest',
#  '73hypothyroid340bryn',
#  '81mammalian176cornell',
#  '55renovate373dugan',
#  '86correct142lindsey',
#  '82dixieland928barton',
#  '36entranceway555chalmers',
#  '38cocklebur600bromley',
#  '61deadlock238gus',
#  '93tor459frigidaire',
#  '77navigable478italian',
#  '87breakup516mcdonald',
#  '89appanage307glasgow',
#  '67honorary395morrison',
#  '98velocity808poincare',
#  '43aunt827wolff',
#  '79tribulate660anatole',
#  '49deceptive954pretoria',
#  '81necromantic372ieee',
#  '83mimesis794palermo',
#  '50sunfish303runge',
#  '71renown666saturday',
#  '53floorboard570switzerland',
#  '97collage915rex',
#  '22hiatus254semite',
#  '80solstice609johann',
#  '11hieratic468jimmie',
#  '65skeleta754griswold',
#  '82alia576buddhist',
#  '73pendant268morrison',
#  '50popish454hippocrates',
#  '36splice289julia',
#  '66cusp128clive',
#  '96woolgather731lyman',
#  '48cairn675anacreon',
#  '69video382addis',
#  '51doubt191mathews',
#  '51workmen697lutz',
#  '92wok214rensselaer',
#  '77church493reid',
#  '59plagiarism544ndjamena',
#  '92insofar383berkowitz',
#  '65viviparous283templeton',
#  '72antedate450marlboro',
#  '80formidable537roger',
#  '75is792foxhall',
#  '72principle503karol',
#  '71abound800mae',
#  '95immiscible147edwin',
#  '84patronage371lisa',
#  '43degassing747kuwait',
#  '78robotics300diebold',
#  '85studio912minsky',
#  '69uptown289poland',
#  '91lodgepole204egyptology',
#  '74ketchup865wei',
#  '17boss924prokofieff',
#  '91erudition105oklahoma',
#  '23bindle871bator',
#  '58sponge919tananarive',
#  '56nucleate951vancouver',
#  '31polyandry766calcutta',
#  '21vaccinate684merck',
#  '46pathway380california',
#  '51sharpen523maseru',
#  '67crush853descartes',
#  '48axis667agnew',
#  '69talisman665emmanuel',
#  '48protocol633saratoga',
#  '28epigrammatic840letitia',
#  '34evensong634suez',
#  '99landhold388exxon',
#  '24marvelous716christine',
#  '44recriminate809elliot',
#  '32kitchen466kirchoff',
#  '43profit278gorham',
#  '73outlawry525tacoma',
#  '24vindictive946theseus',
#  '22deceive118fallopian',
#  '31octahedron434gino',
#  '70mouthful409arlen',
#  '89hilly539georgetown',
#  '49needy315minerva',
#  '45imprimatur530mallory',
#  '18more557halloween',
#  '41stutter328gogh',
#  '38gratitude860irishman',
#  '69plenipotentiary558ali',
#  '62codify493gifford',
#  '12stillwater907anderson',
#  '11scourge205charlie']

# %% [markdown]
# ### Pull all the addresses from the data variable

# %%
ad = re.findall('\s+[0-9]{3}\s+[A-Za-z]+\s+[A-Z]{1}[a-z]+,\s+[A-Z]{1}[a-z]+\s+[A-Z]{2},\s+[0-9]{5}',data)
ad
# Out:
# [' 820 Blackman Blvd, Yokohama WA, 92585',
#  ' 326 Volkswagen Lane, Albany LA, 85265',
#  ' 415 Riley Blvd, Comanche HI, 27071',
#  ' 228 Yeats Ave, Chaplin WY, 40885',
#  ' 496 Atkinson Ave, Passaic SD, 88498',
#  ' 744 Celt Court, Domenico AZ, 57030',
#  ' 900 NH Ave, Simla NY, 96269',
#  ' 462 Irrawaddy Ave, Millie UT, 82466',
#  ' 365 Miriam Blvd, Moldavia LA, 65747',
#  ' 465 Kim Ave, Dryden WI, 14746',
#  ' 203 Wilkins Court, Pamela HI, 48304',
#  ' 727 Italy Ave, Leroy LA, 39059',
#  ' 459 McCann Court, Ulster DC, 50084',
#  ' 358 Cruz Ave, Chiang WY, 53057',
#  ' 643 Esmark Lane, Pam WV, 59039',
#  ' 862 Iran Blvd, Mississippian WY, 33244',
#  ' 952 Haas Court, Tunisia TX, 73729',
#  ' 710 Wadsworth Lane, Cassiopeia AK, 38017',
#  ' 115 USA Court, Willoughby FL, 75661',
#  ' 296 Pentateuch Ave, Gurkha AR, 57873',
#  ' 774 Florentine Blvd, Argonne IN, 83991',
#  ' 282 Jacob Lane, Mrs NJ, 54717',
#  ' 299 Uniroyal Lane, Mendel NC, 63675',
#  ' 521 Lucian Lane, Moluccas CT, 82784',
#  ' 825 Whittier Blvd, Schaefer MT, 76252',
#  ' 542 Wrigley Blvd, Nyquist MS, 33081',
#  ' 431 Aviv Blvd, Knoxville NY, 10225',
#  ' 702 Greek Blvd, Montenegrin IL, 63778',
#  ' 588 Piraeus Ave, Orville KS, 49971',
#  ' 117 Merriam Blvd, Adolph NC, 16254',
#  ' 950 Bordeaux Blvd, Offenbach DE, 14658',
#  ' 302 Neanderthal Court, Luis VA, 14729',
#  ' 494 Sao Court, Jill WA, 24611',
#  ' 830 Islamabad Ave, Zaire NY, 54892',
#  ' 769 Apollonian Court, Del LA, 34413',
#  ' 894 Hutchins Blvd, Jolla AR, 52579',
#  ' 929 Holyoke Blvd, Laidlaw FL, 17034',
#  ' 887 Agway Ave, Nate MO, 41190',
#  ' 131 USN Blvd, Ericsson VT, 47746',
#  ' 666 Capricorn Ave, Hatteras AZ, 92848',
#  ' 243 Frigidaire Lane, Calvary NJ, 56470',
#  ' 141 Nathan Blvd, Carbone AR, 30324',
#  ' 283 Bryn Lane, Ursa PA, 12880',
#  ' 145 CA Lane, Amtrak MN, 92051',
#  ' 221 Pancho Ave, Brussels NC, 39257',
#  ' 572 Verdi Blvd, Rowena ID, 12658',
#  ' 971 Ogden Court, Henrietta NV, 25342',
#  ' 655 Jeffrey Blvd, Tahiti AK, 54259',
#  ' 177 Idaho Lane, Alberto DE, 44044',
#  ' 392 Abramson Court, Falstaff ME, 92060',
#  ' 486 Galileo Blvd, Hispanic WA, 69586',
#  ' 148 Hitler Ave, Mrs KS, 98770',
#  ' 419 Rutledge Lane, Rushmore IN, 53440',
#  ' 650 Pavlov Court, Kirchner WI, 57668',
#  ' 571 Nabisco Ave, Jesuit RI, 77417',
#  ' 275 Vito Lane, Leone IN, 62334',
#  ' 412 Annale Ave, Hillcrest LA, 32451',
#  ' 791 Weston Lane, Millie SC, 34700',
#  ' 830 Dane Ave, Adolph HI, 37443',
#  ' 132 Rutledge Blvd, Europa DC, 23551',
#  ' 723 Nubia Lane, Yost DE, 20538',
#  ' 600 Benedictine Blvd, Rigel AR, 52254',
#  ' 331 Piccadilly Court, Mendel NH, 74220',
#  ' 929 Laurent Ave, Birgit NY, 58199',
#  ' 578 Hudson Lane, Longfellow SC, 67687',
#  ' 761 Alastair Blvd, Bucharest MD, 24208',
#  ' 774 Connie Lane, Fernando HI, 93398',
#  ' 799 MacDonald Lane, Poynting RI, 72562',
#  ' 228 Agnew Blvd, Moluccas WI, 23836',
#  ' 500 Hom Ave, Deanna VA, 21415',
#  ' 862 Onondaga Blvd, Holst MT, 69372',
#  ' 165 Coronado Ave, Baxter VA, 20336',
#  ' 244 Saturn Blvd, Shanghai OH, 33275',
#  ' 730 Antoinette Blvd, Lena IL, 61508',
#  ' 132 Elmsford Court, Brunhilde OH, 49656',
#  ' 278 Chicago Lane, Desmond RI, 69792',
#  ' 891 Turkish Ave, Healey DC, 96972',
#  ' 656 Phobos Ave, Raritan MI, 69865',
#  ' 535 Garfield Blvd, Germany GA, 45038',
#  ' 128 Viet Blvd, Dunlap AR, 64283',
#  ' 294 Stanley Blvd, Akron OH, 65879',
#  ' 556 Hansen Court, Pythagoras OR, 89264',
#  ' 170 Yeager Ave, Maloney AR, 95690',
#  ' 233 Babel Ave, Lathrop OR, 38963',
#  ' 988 Ferdinand Ave, Thelma AZ, 31688',
#  ' 276 Newbold Ave, Marlowe IA, 69984',
#  ' 298 Ulysses Court, Sheraton MN, 50250',
#  ' 793 Garibaldi Court, Dwyer KY, 18066',
#  ' 482 CRT Ave, Mann MS, 16205',
#  ' 203 Crusoe Lane, Rembrandt OK, 87566',
#  ' 673 Baylor Ave, Masonite DE, 10794',
#  ' 869 Riga Court, Angela RI, 10055',
#  ' 625 Carlisle Ave, Hillel RI, 35594',
#  ' 306 Buena Court, Giuliano OH, 81530',
#  ' 378 Manila Court, Gobi OK, 76416',
#  ' 101 Coronado Ave, Vicksburg DE, 25242',
#  ' 538 McDermott Lane, Pepsi MT, 56839',
#  ' 507 Bowdoin Ave, Pittsfield SC, 46683',
#  ' 998 Cleveland Ave, Lusaka OR, 42339',
#  ' 548 SC Court, Pawtucket RI, 69789',
#  ' 425 Fogarty Court, Martha AZ, 73081',
#  ' 939 Crusoe Ave, Io MA, 74496',
#  ' 250 Courtney Ave, Bunsen SC, 88948',
#  ' 767 BMW Ave, Alexandre TN, 38195',
#  ' 947 Bruckner Ave, Elmhurst LA, 93258',
#  ' 105 Cinerama Lane, Charybdis OR, 90983',
#  ' 661 Hobbes Court, Fitzgerald AK, 91490',
#  ' 291 Kettering Lane, Johnson DC, 43507',
#  ' 397 Nordhoff Court, Edgar FL, 18300',
#  ' 393 Nakayama Blvd, Chatham VA, 62850',
#  ' 337 Yucatan Blvd, Olivetti OR, 82307',
#  ' 342 Bernardo Lane, Haynes AZ, 24925',
#  ' 376 Hereford Blvd, Rockefeller HI, 31400',
#  ' 781 Orin Blvd, Laos KY, 92060',
#  ' 119 Reub Court, Akron IL, 25730',
#  ' 147 BP Lane, Alvarez ME, 98993',
#  ' 936 Allis Lane, Weldon NE, 86090',
#  ' 773 NIH Ave, Greenland OR, 70683',
#  ' 644 Jo Ave, Indiana WV, 85135',
#  ' 363 Chesterton Lane, Kikuyu WV, 15342',
#  ' 174 Virginia Blvd, Passaic NV, 22856',
#  ' 111 Englewood Ave, Yamaha SD, 73108',
#  ' 102 PVC Court, Shelley IL, 42266',
#  ' 219 Kiwanis Lane, Antilles IL, 25826',
#  ' 249 Atlantis Court, Frick TN, 38068',
#  ' 317 Lufthansa Ave, Hispanic ID, 38496',
#  ' 924 Aleck Court, Glasgow HI, 29727',
#  ' 496 Hickman Ave, Roosevelt SC, 42695',
#  ' 748 Yates Court, Mafioso SD, 27868',
#  ' 602 Lionel Blvd, Patagonia MT, 14828',
#  ' 681 Denebola Lane, Eagan WV, 20159',
#  ' 996 Canaan Court, Fulton SC, 24753',
#  ' 736 Nguyen Court, Cheshire IA, 87279',
#  ' 375 Davison Ave, Marx CA, 71390',
#  ' 534 Franz Lane, Dixie UT, 77758',
#  ' 513 Palatine Ave, Latin TX, 59735',
#  ' 332 Maynard Court, Diogenes SD, 34355',
#  ' 592 Anaheim Lane, Recife VA, 12822',
#  ' 147 Tristan Ave, Ruth ID, 68514',
#  ' 822 Iraqi Lane, Lourdes LA, 71618',
#  ' 831 Markovian Lane, Colombia TN, 30755',
#  ' 145 Nero Blvd, Lipschitz CT, 67458',
#  ' 939 Linda Blvd, Roman OH, 93322',
#  ' 869 Clemson Court, Lippincott AK, 49164',
#  ' 154 Cochrane Court, Paz MN, 36390',
#  ' 391 Bose Blvd, Niagara KY, 74515',
#  ' 638 Kramer Ave, Manama MT, 42995',
#  ' 294 Levitt Ave, Indus NM, 14428',
#  ' 406 Rachmaninoff Blvd, Dublin AZ, 36519',
#  ' 786 Rhea Blvd, Huntley CO, 11529',
#  ' 242 Maurine Blvd, Kikuyu NH, 51435',
#  ' 469 Marceau Blvd, Northrup SC, 65493',
#  ' 904 Smythe Ave, Seville FL, 47632',
#  ' 314 Pete Blvd, Mabel NM, 12252',
#  ' 592 Liechtenstein Ave, Seychelle NH, 40883',
#  ' 220 Barnhard Court, Lakehurst PA, 24551',
#  ' 813 Stauffer Lane, Donovan VA, 70471',
#  ' 259 Carboniferous Blvd, Croix FL, 14434',
#  ' 177 Yalta Lane, Afrikaner DE, 90235',
#  ' 326 Feldman Ave, Agricola TX, 38749',
#  ' 464 Battelle Ave, Malthusian ID, 44768',
#  ' 683 Thalia Court, Vandenberg NV, 35801',
#  ' 891 Montmartre Ave, Rudyard IL, 23491',
#  ' 883 Jon Blvd, Bootes MS, 79256',
#  ' 356 Neptune Lane, Schubert DC, 37505',
#  ' 228 Faustus Ave, Camille WI, 54799',
#  ' 956 Ponce Ave, Mira GA, 13235',
#  ' 903 Paulson Ave, Stirling KY, 49279',
#  ' 945 Bowen Blvd, Annette OK, 86499',
#  ' 132 FDA Court, Enoch ND, 49024',
#  ' 651 Horace Blvd, Champaign UT, 65865',
#  ' 386 Madsen Blvd, Argentine NC, 61189',
#  ' 817 Waco Lane, Lange MD, 34540',
#  ' 647 Chablis Blvd, April VA, 10874',
#  ' 952 Salk Lane, Mynheer NY, 57702',
#  ' 846 Ibn Lane, Hendrick ND, 36677',
#  ' 691 Moll Ave, Davis KY, 36583',
#  ' 214 Styx Lane, Euler MI, 37904',
#  ' 323 Blomquist Court, Chinaman LA, 37411',
#  ' 268 Bristol Ave, Gwyn RI, 57181',
#  ' 480 Platte Ave, Dorcas TX, 28576',
#  ' 402 Mathews Lane, Afghan ND, 45477',
#  ' 349 Baja Blvd, Serpens IN, 41885',
#  ' 598 Nicaragua Lane, Augean ND, 43913',
#  ' 432 Hebe Lane, Plato NJ, 77620',
#  ' 645 IRS Ave, Collins KS, 38255',
#  ' 215 Carlo Blvd, Weller OK, 34284',
#  ' 307 Engle Court, Hadley KY, 26511',
#  ' 418 Helen Court, Pelham FL, 13861',
#  ' 125 Oberlin Lane, Epstein ME, 52420',
#  ' 427 Mirfak Lane, Leavenworth MN, 26132',
#  ' 396 Kimball Lane, Connors NH, 71490',
#  ' 813 NBC Lane, Knutsen WV, 11574',
#  ' 982 Atlantis Court, Mecca NC, 59045',
#  ' 708 Delhi Lane, Imbrium IN, 27672',
#  ' 796 Celebes Blvd, Morristown MN, 62446',
#  ' 587 Briton Lane, Khartoum UT, 44518',
#  ' 402 Scotia Ave, Tennessee AK, 44928',
#  ' 498 Joseph Court, Collins MS, 16554',
#  ' 126 Marlene Lane, Pakistan KY, 92622',
#  ' 118 Moser Lane, Ian NV, 22314',
#  ' 210 Tulsa Court, Jonas NY, 72709',
#  ' 307 Nagoya Blvd, Dade FL, 34710',
#  ' 138 Corp Court, Chippendale MI, 63141',
#  ' 195 Dartmouth Blvd, Rufus NV, 98008',
#  ' 554 Elgin Blvd, Hernandez NE, 60897',
#  ' 454 Kashmir Court, Sanskrit NV, 93527',
#  ' 625 Epicurean Blvd, Albuquerque VA, 54521',
#  ' 199 Hoyt Court, Purdue MS, 29871',
#  ' 910 Sterno Ave, Nazarene NM, 53922',
#  ' 219 Dickson Court, Peru UT, 21272',
#  ' 953 Gutenberg Ave, Costa IA, 47929',
#  ' 452 Ojibwa Lane, Bellini RI, 87761',
#  ' 295 Tahoe Ave, Antwerp NH, 20305',
#  ' 809 Zoe Lane, Helga CO, 50475',
#  ' 379 Buddha Blvd, Dearborn DC, 68419',
#  ' 749 Huggins Blvd, Ponchartrain AK, 74978',
#  ' 726 Krakow Blvd, Brigham KS, 14648',
#  ' 488 Elliott Lane, Essen ME, 79671',
#  ' 338 Brooklyn Lane, Fahey WI, 55708',
#  ' 491 Spector Ave, Moulton NE, 33213',
#  ' 894 Anacreon Ave, Baudelaire OK, 10216',
#  ' 574 Euphrates Blvd, Perth MO, 59620',
#  ' 369 Celia Ave, Wellesley AK, 21451',
#  ' 612 Levi Ave, Fahey MD, 78876',
#  ' 520 Christendom Blvd, Palmolive CA, 54743',
#  ' 261 Arlene Blvd, Keats TX, 99838',
#  ' 605 Gaelic Court, Chinatown MO, 46905',
#  ' 441 Whitaker Court, Mollie SC, 64399',
#  ' 903 Hermes Court, Coolidge NC, 76102',
#  ' 964 Northampton Court, Ridgway PA, 67493',
#  ' 372 Seattle Lane, Farrell GA, 55451',
#  ' 285 Doris Court, Shiva LA, 82299',
#  ' 173 Ursula Lane, Pulitzer UT, 22054',
#  ' 189 Bowditch Court, Sarah NJ, 74375',
#  ' 218 Alastair Court, Jeannie MD, 50902',
#  ' 723 Lars Blvd, Mattson CO, 42686',
#  ' 902 Deirdre Lane, Britannic VT, 25953',
#  ' 196 Clifton Blvd, Olivetti CA, 98855',
#  ' 471 Sylow Blvd, Cabot MN, 85943',
#  ' 742 Eisenhower Blvd, Winnipesaukee TN, 86311',
#  ' 367 Cecilia Ave, Chalmers CO, 98606',
#  ' 563 GAO Ave, Bootes TX, 54465',
#  ' 301 Alabama Court, Regina VT, 13120',
#  ' 244 Blackstone Blvd, Fiji AR, 68080',
#  ' 708 Deirdre Court, Hiroshima OR, 85585',
#  ' 537 Princeton Lane, Ferrer AK, 32560',
#  ' 100 Alfredo Blvd, Blomberg NY, 61139',
#  ' 331 Jefferson Blvd, Pawtucket GA, 70404',
#  ' 305 Selectric Lane, Glenda ND, 95499',
#  ' 281 Auriga Blvd, Alison NJ, 16617',
#  ' 775 Chantilly Court, Lilly LA, 64745',
#  ' 567 Texaco Ave, Appalachia SC, 43670',
#  ' 391 Penrose Ave, Bolshevism FL, 50911',
#  ' 597 Leo Court, Donahue TX, 50238',
#  ' 504 Matsumoto Ave, Worthington WY, 48306',
#  ' 627 Sylow Blvd, Manama SC, 56721',
#  ' 729 Iranian Blvd, Franz RI, 45566',
#  ' 780 Merck Court, Abraham WY, 40895',
#  ' 353 Gouda Blvd, Slovenia VT, 68300',
#  ' 298 Carmela Ave, Theodore MN, 10495',
#  ' 932 Tobago Court, Fayetteville MS, 80515',
#  ' 826 Bamako Lane, Matthew FL, 27180',
#  ' 148 Appleton Court, Jakarta IL, 55146',
#  ' 768 Sturbridge Court, Mildred FL, 41051',
#  ' 518 Fischer Blvd, Dorothea ND, 17846',
#  ' 388 Matisse Court, Kannada PA, 97435',
#  ' 436 Bucharest Blvd, Clemson MT, 55360',
#  ' 544 Tuscarora Blvd, Adirondack DE, 56174',
#  ' 836 Barnes Lane, Camelot MS, 90734',
#  ' 871 Montrachet Court, Doolittle LA, 15961',
#  ' 782 Charta Court, Waldo SD, 63078',
#  ' 255 Procrustes Ave, Nina AZ, 84596',
#  ' 419 Guelph Blvd, Hun IN, 28262',
#  ' 968 Babylon Ave, Katherine MA, 71192',
#  ' 918 Nagasaki Ave, Miltonic WI, 25980',
#  ' 358 Roentgen Lane, Babel NJ, 29908',
#  ' 109 Palestine Court, Princeton FL, 79237',
#  ' 645 Skopje Court, Ptolemy IL, 36850',
#  ' 334 Wendell Lane, Afghanistan KY, 28580',
#  ' 637 Charta Blvd, Flo AZ, 21057',
#  ' 393 Zorn Court, Aaron RI, 31574',
#  ' 523 McCormick Ave, Agatha IA, 11524',
#  ' 355 NIH Court, Bernstein NV, 52126',
#  ' 162 Balinese Ave, Allstate FL, 77691',
#  ' 357 Duma Lane, Connors MD, 11728',
#  ' 764 Peterson Court, Neptune CA, 51040',
#  ' 364 Yaounde Court, Melanie MI, 67585',
#  ' 708 Christie Blvd, Purcell NE, 84341',
#  ' 581 Atreus Court, Amtrak WV, 25477',
#  ' 123 Shanghai Lane, Galapagos AK, 46861',
#  ' 471 Rachel Court, Angelo AR, 69946',
#  ' 971 Scarborough Blvd, Fleming WY, 37502',
#  ' 149 Tegucigalpa Blvd, Mali NY, 85274',
#  ' 929 Phobos Blvd, Nordic RI, 18817',
#  ' 825 Dido Court, Twombly IL, 11801',
#  ' 542 Baxter Lane, Kaskaskia MD, 21756',
#  ' 475 Pleiades Blvd, Cruickshank SC, 86967',
#  ' 952 Vella Ave, Sherrill AK, 68778',
#  ' 542 AAAS Blvd, Belfast MS, 77318',
#  ' 730 Ibn Lane, Cheyenne MA, 79640',
#  ' 747 Gus Ave, Peoria HI, 77117',
#  ' 417 NSF Blvd, Lincoln WA, 93032',
#  ' 813 Noah Court, Horatio FL, 10281',
#  ' 275 Piccadilly Court, Boca VT, 74176',
#  ' 193 Nell Ave, Arabic TX, 71664',
#  ' 795 Denver Ave, Moines IA, 72745',
#  ' 542 Aides Lane, Nestor NJ, 24026',
#  ' 123 Rastus Ave, Raoul MD, 58389',
#  ' 386 Galapagos Ave, Kidde NJ, 69794',
#  ' 387 Madsen Blvd, Ghanian NY, 28299',
#  ' 746 Pluto Lane, Newfoundland VA, 84987',
#  ' 404 Phil Court, Miranda DE, 64522',
#  ' 393 Caruso Blvd, Katharine NH, 39077',
#  ' 274 Jacobite Blvd, Potts IA, 72523',
#  ' 840 Powell Ave, Persia OR, 19714',
#  ' 709 Lloyd Court, Knutsen IL, 83104',
#  ' 918 Falkland Blvd, Lynchburg RI, 14835',
#  ' 733 Hayden Lane, Joanne HI, 28790',
#  ' 917 Jacobus Lane, Sims CA, 79620',
#  ' 688 Craig Ave, Motorola UT, 14427',
#  ' 797 Balinese Court, Bern NY, 77740',
#  ' 818 Mycenaean Blvd, Denny KY, 88241',
#  ' 955 Huntley Blvd, Putnam IN, 66814',
#  ' 107 Auerbach Blvd, Devon MI, 82468',
#  ' 997 Pamela Court, Tim OK, 98396',
#  ' 445 IEEE Blvd, Lindbergh CO, 11118',
#  ' 514 Stokes Blvd, Eire WV, 20779',
#  ' 589 Rowland Blvd, Eire TX, 90979',
#  ' 654 Noll Blvd, Noel MD, 63123',
#  ' 476 Vermont Ave, Susan VT, 36872',
#  ' 759 Hutchison Ave, Priscilla VT, 85182',
#  ' 419 Sloane Lane, Keyes ME, 70198',
#  ' 897 Brett Lane, Saturday AZ, 16253',
#  ' 210 Kirchner Ave, Saviour CO, 17328',
#  ' 244 Heidelberg Ave, Jacobson MO, 90360',
#  ' 491 Moulton Lane, Perseus KS, 21569',
#  ' 211 Winnetka Lane, Allegheny OR, 70979',
#  ' 593 Cruz Court, Marceau AR, 32957',
#  ' 440 Constantinople Court, Huber WV, 40462',
#  ' 890 AZ Court, Zion MS, 74188',
#  ' 440 Pyrex Court, Erato IA, 78381',
#  ' 537 Foxhall Blvd, Kalmuk KS, 28511',
#  ' 202 Botswana Court, Narbonne TN, 90155',
#  ' 719 Hippocratic Court, Aeolus IL, 60774',
#  ' 985 Ingersoll Court, Brazzaville NE, 71065',
#  ' 999 Phobos Lane, Flagler AZ, 43285',
#  ' 246 Texas Ave, Mawr NY, 94656',
#  ' 183 Klan Court, Clint MD, 32016',
#  ' 244 Fredericton Court, Fiske MN, 47990',
#  ' 496 Kiewit Court, Charleston KY, 91945',
#  ' 279 Somerville Lane, Emery MS, 62054',
#  ' 822 Kirov Court, Alison NV, 59115',
#  ' 761 Prussia Ave, Phipps IN, 21480',
#  ' 212 Crispin Blvd, Illinois NC, 57157',
#  ' 314 EPA Ave, Mississippian OK, 56238',
#  ' 384 Randall Lane, Israel UT, 55522',
#  ' 470 July Lane, Crowley NV, 57802',
#  ' 681 Kelsey Blvd, Bernardo MO, 64030',
#  ' 426 Josef Blvd, Ypsilanti MD, 37614',
#  ' 226 Oceania Blvd, Haas WI, 59246',
#  ' 843 Nostrand Court, Amarillo ME, 54632',
#  ' 994 Corey Court, Bordeaux NH, 51398',
#  ' 536 Diana Blvd, Sinbad NE, 96087',
#  ' 685 Cerberus Ave, Frankel NC, 37609',
#  ' 835 Pentecost Lane, Datsun IL, 15586',
#  ' 914 Europe Lane, Lilly OH, 50569',
#  ' 313 Lissajous Ave, Cinerama ME, 60214',
#  ' 259 Lufthansa Blvd, Sylow HI, 91423',
#  ' 242 Burundi Blvd, Formosa IA, 58859',
#  ' 232 Ben Blvd, Pavlov AK, 61888',
#  ' 738 Seychelle Ave, Truman VA, 22615',
#  ' 649 Thessaly Blvd, Hebrew OH, 87023',
#  ' 513 GA Blvd, Larson MI, 96089',
#  ' 525 Heisenberg Court, Devon WA, 19193',
#  ' 765 Ellison Ave, Parmesan KY, 33445',
#  ' 568 Peterson Court, Diocletian MI, 59900',
#  ' 862 Burke Blvd, Trastevere MO, 54856',
#  ' 558 Albrecht Blvd, Strom OK, 34998',
#  ' 573 Dahl Lane, Chinamen HI, 45476',
#  ' 929 Pict Blvd, Finnegan AK, 90191',
#  ' 707 Dearborn Ave, Jeffrey SC, 17411',
#  ' 638 Beethoven Ave, Vivaldi KY, 93945',
#  ' 229 Fuji Blvd, Worcester NJ, 35555',
#  ' 157 Portugal Court, Johansen CT, 95851',
#  ' 554 Kendall Ave, Beowulf CO, 47464',
#  ' 287 Kemp Ave, Cherokee ME, 95117',
#  ' 620 Langley Ave, Bootes UT, 65706',
#  ' 518 Apocrypha Lane, Rodgers CT, 70594',
#  ' 314 Vivian Court, Caviness ID, 76869',
#  ' 673 Lillian Court, Chungking GA, 90845',
#  ' 331 Amazon Court, Odysseus WI, 98119',
#  ' 806 Rousseau Court, Caucasus WV, 55477',
#  ' 543 Fulton Lane, Atkinson MN, 17799',
#  ' 556 Quantico Lane, Bragg NC, 36749',
#  ' 679 Aquila Lane, Habib RI, 81740',
#  ' 530 Strickland Lane, Francoise NV, 79490',
#  ' 846 Meistersinger Lane, Shakespearian IL, 65801',
#  ' 234 Abbott Ave, Sebastian CO, 90685',
#  ' 805 RSVP Blvd, Escherichia NM, 42293',
#  ' 917 Milwaukee Lane, Smyrna SC, 34948',
#  ' 430 CBS Blvd, Lana OR, 71737',
#  ' 519 Ceres Lane, Gauguin WI, 76715',
#  ' 256 Abyssinia Blvd, Leningrad MN, 76930',
#  ' 932 Lakehurst Blvd, Panamanian CO, 54836',
#  ' 396 Hess Blvd, Gloria OK, 79326',
#  ' 556 Sioux Lane, Sikkim TX, 95044',
#  ' 694 Matson Court, Shenandoah OK, 99118',
#  ' 728 Paleolithic Ave, Calgary NV, 14424',
#  ' 475 Edison Blvd, Arlington OR, 14843',
#  ' 228 Lebesgue Ave, Laszlo VT, 93570',
#  ' 757 Gemini Lane, Chesapeake AK, 76927',
#  ' 831 Waring Blvd, Sumatra WV, 34745',
#  ' 183 Esther Ave, Japan WI, 15295',
#  ' 543 Harris Ave, Draconian KS, 48966',
#  ' 984 Mueller Blvd, Steen NM, 53168',
#  ' 740 Laredo Blvd, Hatteras GA, 76266',
#  ' 107 Kirchner Ave, Honduras SD, 34874',
#  ' 103 Norway Ave, Conklin TX, 22487',
#  ' 551 Teledyne Blvd, Dutchman MS, 54746',
#  ' 184 Helena Lane, Heine MI, 37981',
#  ' 680 Gilead Lane, Benedictine NC, 18536',
#  ' 604 Indoeuropean Ave, Jesse MO, 97663',
#  ' 356 Segundo Court, Blvd IA, 34820',
#  ' 555 Peking Blvd, Hubbard IL, 52254',
#  ' 234 GNP Blvd, Rosetta OR, 53629',
#  ' 881 Charon Court, Sunday TN, 54480',
#  ' 929 Patagonia Court, Otto DE, 88799',
#  ' 449 Davis Lane, Gabriel NM, 81598',
#  ' 193 Barnard Court, Margery WI, 85654',
#  ' 402 Harley Court, Semite KY, 75330',
#  ' 292 Aquarius Court, Coronado IN, 88458',
#  ' 556 Murphy Lane, Alton DE, 78543',
#  ' 211 Senegal Court, Paterson NH, 99812',
#  ' 427 Bella Lane, Siberia KY, 41199',
#  ' 772 Wainwright Ave, Olympia MS, 28215',
#  ' 404 Cedric Ave, Mabel MA, 13325',
#  ' 632 Langmuir Ave, Talmudic SC, 79745',
#  ' 523 Multics Lane, Chattanooga DE, 98226',
#  ' 871 OPEC Blvd, Gerhard MN, 70802',
#  ' 765 Carla Blvd, Bronx CA, 95037',
#  ' 237 Samson Lane, Electra MN, 49509',
#  ' 772 Richardson Court, Henri GA, 48773',
#  ' 213 Newman Lane, Duquesne NV, 14556',
#  ' 853 Flynn Lane, Exeter PA, 92674',
#  ' 324 Levis Court, Sylvania CT, 50738',
#  ' 857 Sherwood Lane, Emil NC, 79623',
#  ' 774 Dhabi Blvd, Wakefield DE, 86205',
#  ' 987 Honolulu Ave, Geraldine LA, 73623',
#  ' 844 Nixon Court, Lombard ID, 19805',
#  ' 228 Adelaide Ave, Ragusan VT, 14544',
#  ' 825 Laurent Lane, Huntley MS, 28435',
#  ' 211 Sahara Blvd, Bechtel CT, 93683',
#  ' 944 Nazareth Court, Weiss NH, 52888',
#  ' 170 Erich Court, Aiken WA, 79105',
#  ' 143 Proserpine Court, Moore MO, 21098',
#  ' 118 NCAA Blvd, Linda WV, 35592',
#  ' 488 Kelsey Court, Fijian VA, 56185',
#  ' 493 Lipschitz Blvd, Effie WI, 61346',
#  ' 236 Whitcomb Lane, Negroes WA, 83134',
#  ' 735 Polk Ave, Ned TN, 35482',
#  ' 356 Bayport Ave, Mackinaw MA, 24473',
#  ' 414 Gil Blvd, Gothic UT, 93940',
#  ' 743 Angora Court, Crockett SC, 96500',
#  ' 322 Skippy Lane, Fenton LA, 40560',
#  ' 228 Pauli Court, Lola NJ, 33021',
#  ' 699 Casey Ave, Frey WI, 33329',
#  ' 505 Bertha Court, Woodbury WA, 36308',
#  ' 836 Diophantine Lane, Whippany HI, 95318',
#  ' 664 Nabisco Court, Purina RI, 80453',
#  ' 112 Angie Court, Lubbock SC, 13233',
#  ' 731 Denebola Court, Purdue NH, 15577',
#  ' 594 Buchwald Lane, Barnum MS, 99443',
#  ' 632 Pulitzer Blvd, Hanukkah ID, 87251',
#  ' 217 Garrett Court, Boswell NY, 10279',
#  ' 619 Egan Court, Nebuchadnezzar ME, 66786',
#  ' 252 Churchillian Blvd, Malone NJ, 72832',
#  ' 413 Mona Lane, Isolde DE, 12562',
#  ' 266 Salem Blvd, Mickey NY, 24099',
#  ' 207 Huber Court, Indus OR, 91503',
#  ' 645 Andrei Ave, Debbie UT, 14385',
#  ' 494 Samson Ave, Goodrich MI, 34717',
#  ' 854 Julie Blvd, Barry GA, 84297',
#  ' 247 Boyd Lane, Olympia NE, 48767',
#  ' 532 Durkee Lane, Morley AK, 33521',
#  ' 647 Denver Lane, Kowalewski LA, 59796',
#  ' 400 Madison Court, Burke WI, 88112',
#  ' 335 Prentice Blvd, Berwick OH, 80626',
#  ' 394 Rebecca Court, John OH, 27936',
#  ' 999 Berniece Ave, Madras ND, 35231',
#  ' 903 Laidlaw Lane, Dunlap MS, 17008',
#  ' 636 Tommie Lane, Lancaster WA, 20026',
#  ' 507 Gregg Ave, Tegucigalpa WY, 31635',
#  ' 483 Guthrie Ave, Antigone NC, 37393',
#  ' 617 Kettering Court, Freddy CT, 90584',
#  ' 492 Hibernia Blvd, Everglade MI, 62120',
#  ' 743 Herculean Lane, Isis SC, 69038',
#  ' 786 Sarasota Court, Uranus CT, 74271',
#  ' 610 Cameron Lane, Pakistani WA, 62288',
#  ' 735 Raritan Blvd, Jesse FL, 17770',
#  ' 165 Bolshevik Court, Rio MI, 54891',
#  ' 407 Mallory Ave, Stafford NJ, 60118',
#  ' 924 Romeo Lane, Muong SD, 77904',
#  ' 253 Aeneas Lane, Champaign ID, 43254',
#  ' 216 Allentown Blvd, Philadelphia VT, 75869',
#  ' 404 Miranda Ave, Parsi CA, 62036',
#  ' 360 Sachs Blvd, Beethoven MS, 80660',
#  ' 222 Doria Lane, Fitzgerald NM, 80398',
#  ' 313 Lenore Court, Nielson NM, 53318',
#  ' 315 Malden Blvd, Augustus FL, 27147',
#  ' 804 Holstein Blvd, Lancelot ME, 56600',
#  ' 270 Grayson Lane, Middletown HI, 28814',
#  ' 531 Delano Lane, Odessa IA, 11321',
#  ' 392 Holcomb Lane, Caldwell AR, 60663',
#  ' 698 Hickman Court, Valerie NJ, 56810',
#  ' 543 Schweitzer Blvd, Perseid FL, 30185',
#  ' 285 Roxbury Blvd, Sutton NM, 82954',
#  ' 859 Cynthia Blvd, Mervin MN, 14114',
#  ' 170 Nubia Ave, Reinhold PA, 20262',
#  ' 592 Baghdad Ave, Sanchez OK, 23246',
#  ' 509 Courtney Lane, Asiatic CA, 62614',
#  ' 371 Hermann Lane, Olympic MD, 76613',
#  ' 516 Neil Blvd, Boris MI, 93428',
#  ' 494 Susanne Blvd, Seth WI, 19555',
#  ' 558 Perle Lane, Irma NJ, 32298',
#  ' 403 Essen Ave, Tutenkhamon NE, 14424',
#  ' 772 Notre Blvd, Brownian MA, 99081',
#  ' 360 Muenster Lane, Hubbard NV, 45908',
#  ' 840 Randall Court, Hannah ME, 94648',
#  ' 943 Gaul Lane, Waldorf ME, 97564',
#  ' 678 Bimini Lane, Victoria CO, 47691',
#  ' 874 Jude Lane, Gary OR, 90133',
#  ' 102 Athens Ave, Berea AK, 36368',
#  ' 113 Hobbes Court, Olympic IN, 17716',
#  ' 625 Edwardian Blvd, Andorra NH, 21211',
#  ' 508 McBride Lane, Horatio MO, 17608',
#  ' 797 Rollins Ave, Pakistan NH, 10962',
#  ' 221 Mendelssohn Court, Rd ID, 46867',
#  ' 355 Kevin Lane, Hutchins IA, 42233',
#  ' 698 Allis Lane, Jacobean UT, 34176',
#  ' 822 Brumidi Ave, Pollard NV, 63136',
#  ' 712 Paula Ave, Downey OK, 34125',
#  ' 527 Durham Ave, Dryden SC, 11316',
#  ' 464 Boeing Court, Coleridge OH, 90180',
#  ' 203 Galloway Lane, Dairylea ND, 57838',
#  ' 700 Ababa Court, Blomquist NH, 67210',
#  ' 840 Wilkins Court, Dinah WY, 18673',
#  ' 976 Nippon Blvd, Brownian MI, 61400',
#  ' 290 Norton Lane, Wooster NV, 52056',
#  ' 672 Wesleyan Lane, Audrey MT, 28705',
#  ' 646 Lubbock Blvd, Melvin AZ, 33918',
#  ' 680 Malabar Ave, Dec IL, 64218',
#  ' 445 Wasserman Court, Sheila AK, 58209',
#  ' 600 Valkyrie Blvd, Peoria MO, 23478',
#  ' 646 Justine Court, Lauderdale PA, 61239',
#  ' 628 Prescott Court, Littleton CT, 92861',
#  ' 604 Worthington Lane, Chad MI, 27520',
#  ' 461 Leo Court, Portsmouth MI, 93131',
#  ' 298 Creon Ave, Saxon HI, 56735',
#  ' 696 Langmuir Blvd, Orville VA, 96708',
#  ' 693 Himalaya Lane, Isaac AZ, 93383',
#  ' 397 Zoroaster Ave, Maxine TN, 36854',
#  ' 313 Bizet Ave, Dahomey IN, 76492',
#  ' 616 Cornwall Court, Lauderdale FL, 75818',
#  ' 998 Sofia Ave, Viet HI, 58608',
#  ' 326 Majorca Blvd, Bernhard CT, 84004',
#  ' 631 Dalzell Ave, Montmartre NC, 14531',
#  ' 653 Amman Blvd, Callisto TN, 19058',
#  ' 720 Guam Court, Sergei FL, 70649',
#  ' 197 WV Lane, Hollerith NC, 13985',
#  ' 663 Berniece Lane, Brahmaputra OR, 55915',
#  ' 653 Spaulding Lane, Salesian IA, 81692',
#  ' 478 Alcestis Court, Baptist MA, 69230',
#  ' 267 Mach Blvd, Moldavia KS, 27115',
#  ' 555 Harvey Blvd, Azerbaijan NC, 89742',
#  ' 490 Kirchoff Court, Stuart WA, 39339',
#  ' 939 Errol Lane, Culver RI, 24390',
#  ' 881 Lutheran Court, Braille MN, 16874',
#  ' 361 Jackie Blvd, Gaul IL, 80873',
#  ' 860 Wednesday Ave, Adamson OR, 89281',
#  ' 936 Saginaw Lane, Seoul MT, 47996',
#  ' 915 Whitlock Lane, Gothic VA, 12300',
#  ' 988 Pomona Ave, Lancashire FL, 37248',
#  ' 159 Pinsky Ave, Pinsky MA, 27660',
#  ' 417 Josiah Blvd, Citroen IL, 73148',
#  ' 249 Berenices Blvd, Brussels OH, 62510',
#  ' 457 Pierre Blvd, Blenheim OH, 38100',
#  ' 705 Browne Lane, Hal TN, 70101',
#  ' 653 Rangoon Court, Jolla ID, 58461',
#  ' 176 Wakefield Ave, Adlerian TX, 23524',
#  ' 575 Sterno Ave, Squibb ME, 22576',
#  ' 564 Benedictine Blvd, Protophyta TN, 24892',
#  ' 711 Tass Court, Datsun NC, 88311',
#  ' 352 Bernardo Court, Euphrates NC, 48754',
#  ' 321 Blumenthal Lane, Georgia OH, 56982',
#  ' 525 Aeneas Lane, Putnam TN, 14710',
#  ' 564 Lounsbury Blvd, Atkins MI, 44785',
#  ' 310 Choctaw Ave, Nathaniel IL, 17787',
#  ' 904 Kamchatka Lane, Asher KS, 50615',
#  ' 535 Leander Lane, Clarence GA, 29773',
#  ' 561 Kigali Lane, Earthman GA, 69577',
#  ' 758 Hollister Ave, Pomona OR, 97510',
#  ' 853 TEX Lane, Anna SD, 49407',
#  ' 616 Staten Ave, Protophyta GA, 83344',
#  ' 124 Linotype Lane, Urbana WY, 92972',
#  ' 686 Maxwellian Lane, Lathrop MT, 65669',
#  ' 935 Des Lane, Alex AZ, 18206',
#  ' 995 Anabel Ave, Holcomb WI, 72067',
#  ' 225 Manville Ave, Downey ND, 55844',
#  ' 512 Merck Blvd, Pratt DE, 78281',
#  ' 228 Mackey Ave, Hattiesburg VA, 48115',
#  ' 358 Fresnel Ave, Lucian AR, 26597',
#  ' 577 McCallum Blvd, Sophie MN, 29872',
#  ' 837 Della Blvd, Somalia NY, 62456',
#  ' 658 Cavendish Court, Dodd RI, 11657',
#  ' 254 Thornton Blvd, Caleb KY, 31403',
#  ' 895 Lachesis Ave, Gates MO, 72457',
#  ' 883 Jackson Ave, Hoover SD, 80892',
#  ' 414 Osborne Blvd, Dortmund NJ, 71142',
#  ' 176 Gail Blvd, Octavia MT, 79423',
#  ' 487 Sirius Court, Clytemnestra OR, 16215',
#  ' 205 Disneyland Ave, Cathy CA, 53482',
#  ' 409 Monaco Ave, Heraclitus NV, 10636',
#  ' 976 Perkins Ave, Travis HI, 95744',
#  ' 206 Everett Blvd, Desmond ID, 65587',
#  ' 181 Rosenberg Blvd, Shelley WY, 27207',
#  ' 910 Waterloo Lane, Sweeney GA, 16859',
#  ' 326 Gus Court, Kermit DC, 15756',
#  ' 204 Prokofieff Court, Picasso NC, 76067',
#  ' 214 Runnymede Court, Manhattan AK, 14154',
#  ' 980 Fruehauf Ave, Clyde PA, 92291',
#  ' 803 Granville Ave, Domenico DE, 29854',
#  ' 901 Janeiro Lane, Barnes MD, 94058',
#  ' 501 Jeff Lane, Noetherian AZ, 66939',
#  ' 315 Feb Court, Teddy MT, 97974',
#  ' 821 Celanese Lane, Pygmalion WA, 94357',
#  ' 314 Ike Blvd, Carlson PA, 62723',
#  ' 480 Beloit Lane, Raytheon NM, 78030',
#  ' 529 Kalmuk Blvd, Sunnyvale AR, 75344',
#  ' 941 Hempstead Court, Gladstone OH, 91802',
#  ' 292 Canis Court, Dutchman WI, 67620',
#  ' 776 Kabuki Lane, Asilomar CT, 44823',
#  ' 523 Chicago Blvd, Pulitzer AK, 97673',
#  ' 945 Wainwright Court, Steele RI, 87620',
#  ' 502 Bahrein Blvd, Gilead DC, 53926',
#  ' 839 Fortescue Court, Saudi WI, 96494',
#  ' 160 Charlottesville Blvd, Mesozoic NJ, 12976',
#  ' 308 Sara Lane, Schofield VT, 43090',
#  ' 620 French Blvd, Hester IL, 16367',
#  ' 392 Bayesian Lane, Wichita IN, 40404',
#  ' 838 Yellowstone Lane, Keller WI, 11569',
#  ' 177 Helvetica Lane, Henley IA, 10992',
#  ' 905 Barlow Court, Khartoum OH, 78101',
#  ' 952 Planck Court, Hanson WI, 81215',
#  ' 177 Minnesota Ave, Sebastian TN, 26231',
#  ' 181 Everglade Lane, Mavis WY, 12179',
#  ' 388 Feb Ave, Williamsburg MD, 47199',
#  ' 535 Armstrong Ave, Niobe NJ, 81040',
#  ' 448 Elizabethan Court, Friday MO, 70715',
#  ' 779 Johannesburg Blvd, Mississippi MO, 76182',
#  ' 732 Galveston Ave, Harlem NM, 96971',
#  ' 169 Muenster Lane, Frankel MA, 93264',
#  ' 974 Ethel Court, Farkas HI, 68388',
#  ' 469 Nostradamus Blvd, Eire PA, 61521',
#  ' 353 Bromfield Blvd, Estonia FL, 90470',
#  ' 809 Barbara Lane, Laocoon WY, 52211',
#  ' 495 Faraday Lane, Zeus ME, 76913',
#  ' 161 Joshua Court, Etruria TX, 27488',
#  ' 577 Hines Ave, Richard NV, 29644',
#  ' 154 Burke Blvd, Ehrlich PA, 79955',
#  ' 328 Edmonds Blvd, Garth NV, 27369',
#  ' 889 Gunther Lane, Mickey SC, 55697',
#  ' 572 Parthenon Court, Hom AZ, 95900',
#  ' 711 Miltonic Court, Ahmedabad AK, 38888',
#  ' 485 Piscataway Blvd, Lebesgue HI, 55772',
#  ' 428 Seton Lane, Somerset KY, 16471',
#  ' 450 Andersen Blvd, Rube MO, 23052',
#  ' 468 Eocene Court, Marriott ND, 59425',
#  ' 824 Tokyo Blvd, Sylow CA, 15799',
#  ' 584 Celebes Court, Cyprus NY, 32345',
#  ' 291 Allegra Ave, Victoria DE, 14965',
#  ' 809 Matisse Ave, Hager DC, 15976',
#  ' 954 Lund Court, Parke OH, 87844',
#  ' 792 NCO Blvd, Jura DC, 46100',
#  ' 319 Denton Blvd, Patterson WY, 71418',
#  ' 837 Cameroun Blvd, Kamchatka RI, 49707',
#  ' 246 Irving Lane, Lin MS, 65247',
#  ' 682 Lynchburg Blvd, Clapeyron NE, 60360',
#  ' 541 Milton Ave, Brookline DE, 87089',
#  ' 132 Marshall Blvd, Bette FL, 36264',
#  ' 167 Lounsbury Court, Lester CT, 21181',
#  ' 319 Syracuse Lane, Cunningham WI, 48789',
#  ' 435 Penh Court, Siberia DE, 62419',
#  ' 790 Shattuck Blvd, Rowley VT, 78141',
#  ' 803 Oscar Court, Brent ME, 70115',
#  ' 731 Trobriand Lane, Parsifal TN, 52971',
#  ' 250 Marino Court, Brownian IN, 20725',
#  ' 165 Alger Lane, Phipps WI, 32348',
#  ' 842 Kline Ave, Nobel IL, 57782',
#  ' 131 Mukden Court, Ahmedabad ID, 77591',
#  ' 347 Bavaria Court, Basel CO, 86941',
#  ' 863 Gaston Blvd, Dearborn MA, 80509',
#  ' 925 Telex Court, Janeiro RI, 64269',
#  ' 837 Kensington Blvd, Kikuyu DE, 50779',
#  ' 769 Galen Blvd, Ely HI, 54883',
#  ' 102 Voltaire Lane, Pinehurst KY, 89596',
#  ' 699 Pasadena Blvd, Astarte LA, 36425',
#  ' 221 SST Ave, Goldstein ME, 17587',
#  ' 420 Slovenia Court, Hudson OR, 24106',
#  ' 134 Schultz Blvd, Vivian NC, 48793',
#  ' 978 Euclid Ave, Sinology WI, 65918',
#  ' 568 Sardinia Ave, Antares WI, 70362',
#  ' 922 Daly Ave, Euterpe MA, 13224',
#  ' 484 Sinbad Blvd, Britannica DC, 11622',
#  ' 147 Freddy Court, Bergland AK, 30184',
#  ' 199 Viennese Ave, Salerno SD, 43631',
#  ' 129 Sri Blvd, Harlan CT, 53745',
#  ' 596 Barnard Lane, Pitt IL, 44106',
#  ' 161 Marc Ave, Delia MT, 99746',
#  ' 309 McGinnis Blvd, Andrew MI, 81692',
#  ' 683 Hanukkah Ave, Osgood WI, 71677',
#  ' 503 Michaelangelo Blvd, Alton VT, 71924',
#  ' 651 Antilles Ave, Arapaho NM, 53841',
#  ' 297 Mexico Blvd, Joseph MA, 78738',
#  ' 420 Gary Court, Waals TN, 69877',
#  ' 527 Kyoto Blvd, Oldsmobile MN, 38472',
#  ' 150 Pelham Lane, Brownian VT, 96436',
#  ' 638 Kilimanjaro Court, Ptolemaic WV, 29023']

# %% [markdown]
# ### Which state had the most addresses in your data?

# %%
import pandas as pd

# %%
di = {}
stat = re.findall('\s+([A-Z]{2},)',data)
se = pd.Series(stat)
se.value_counts()
# Out:
# WI,    26
# IL,    24
# FL,    21
# NC,    20
# SC,    20
# KY,    20
# NJ,    20
# AK,    20
# DE,    19
# MI,    19
# OR,    19
# HI,    19
# RI,    19
# MS,    18
# NV,    18
# NY,    17
# MN,    17
# OH,    17
# ME,    16
# TN,    16
# AZ,    16
# VT,    15
# LA,    15
# WA,    15
# IN,    15
# NH,    14
# MD,    14
# MO,    14
# OK,    14
# WY,    14
# MT,    14
# IA,    14
# PA,    14
# VA,    14
# TX,    13
# UT,    13
# GA,    13
# CT,    13
# ND,    12
# DC,    12
# AR,    12
# CO,    12
# NM,    12
# SD,    12
# WV,    12
# ID,    12
# MA,    12
# CA,    12
# NE,    10
# KS,    10
# dtype: int64

# %% [markdown]
# ### Do we have any famous people in our data?
# #### Check to see if there are any user names that are also city/street names

# %%
n = re.findall('\s+[A-Z]{1}[a-z]+\s+[A-Z]{1}[a-z]+',data)

# %%
for name in names:
    for nname in ad:
        if name not in nname:
            continue
        else:
            print name

# %% [markdown]
# ### What is the value count of the zipcodes in your addresses?

# %%
zips = re.findall('\s+[0-9]{5}',data)
zi = pd.Series(zips)
zi.value_counts()
# Out:
#  14424    2
#  92060    2
#  81692    2
#  52254    2
#  40404    1
#  90470    1
#  54521    1
#  73729    1
#  65021    1
#  61521    1
#  19555    1
#  91490    1
#  47746    1
#  52971    1
#  20026    1
#  55844    1
#  44768    1
#  54799    1
#  79955    1
#  94656    1
#  86205    1
#  14965    1
#  63002    1
#  29727    1
#  98008    1
#  54892    1
#  18300    1
#  29871    1
#  82288    1
#  43990    1
#          ..
#  68080    1
#  41038    1
#  49279    1
#  63778    1
#  92291    1
#  55360    1
#  71737    1
#  20336    1
#  13985    1
#  50084    1
#  48789    1
#  77691    1
#  82954    1
#  59425    1
#  38888    1
#  96089    1
#  74496    1
#  37411    1
#  42995    1
#  36850    1
#  17770    1
#  70979    1
#  48115    1
#  95851    1
#  14385    1
#  36854    1
#  97673    1
#  49656    1
#  37904    1
#  26132    1
# dtype: int64
